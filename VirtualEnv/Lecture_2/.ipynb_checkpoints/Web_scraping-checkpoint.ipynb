# %% [markdown]
# # Web Scraping

# %% [markdown]
# #### Si vuole fare Web Scraping sul sito di Amazon per fare delle statistiche su un determinato prodotto

# %% [markdown]
# ## 1. Analisi del DOM ed Estrazione Automatica¶

# %%
import requests
from bs4 import BeautifulSoup as soup # serve per analizzare il contenuto della pagina web

page_url = "https://www.amazon.it/s?k=occhiali+da+sole&crid=3NM9B3AU1ARTQ&sprefix=%2Caps%2C111&ref=nb_sb_ss_recent_1_0_recent"

HEADERS = {
    'User-Agent': ('Mozilla/5.0 (X11; Linux x86_64)'
                    'AppleWebKit/537.36 (KHTML, like Gecko)'
                    'Chrome/44.0.2403.157 Safari/537.36'),
    'Accept-Language': 'en-US, en;q=0.5'
}

# %%
def scrape_page(page_url, _records = None):
    if _records is None:
        _records = []
    html = requests.get(page_url, headers = HEADERS) # richiesta GET per scaricare il contenuto della pagina
    page_soup = soup(html.text)
    containers = page_soup.findAll('div',{'class':'puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-vwvhvgkypx2z322f29wcc4lx0s s-latency-cf-section puis-card-border'})
    # 'findAll' restituirà una Resultset di oggetti BeautifulSoup corrispondenti agli elementi trovati che soddisfano i criteri specificati.
    
    for container in containers:
        manufacturer = container.findAll('span',{'class':'a-size-base-plus a-color-base'})[0].text   # nome produttore
        model = container.findAll('span',{'class':'a-size-base-plus a-color-base a-text-normal'})[0].text  # modello 
        img_url = container.findAll('div',{'class':'a-section aok-relative s-image-tall-aspect'})[0].img['src']   # immagine
        try:
            price = container.findAll('span',{'class':'a-price-whole'})[0].text   # prezzo
            price = float(price.replace(',','.'))
        except:
            price = 0
        try:
            review_count = container.findAll('span',{'class':'a-size-base s-underline-text'})[0].text   # numero di recensioni
            review_count = int(review_count.replace('.', ''))
        except:
            review_count = 0
        try:
            rating = container.findAll('span',{'class':'a-icon-alt'})[0].text   # valutazione
            rating = float(rating.replace(' su 5 stelle', '').replace(',', '.'))
        except:
            rating=0
        _records.append([manufacturer, model, img_url, price, review_count, rating])
        
    return _records

# %%
import pandas as pd

records = scrape_page(page_url)
data = pd.DataFrame(records, columns=['manufacturer','model','img_url','price','review_count','rating']) # costruisco il DataFrame

# %%
data.info()
print("\n\n")
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  60 non-null     object
#  1   model         60 non-null     object
#  2   img_url       60 non-null     object
#  3   price         60 non-null     float64
#  4   review_count  60 non-null     int64
#  5   rating        60 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.9+ KB
#       manufacturer                                              model  \
# 0     grinderPUNCH  Occhiali da sole XL da uomo con montatura larg...
# 1     grinderPUNCH  Occhiali da sole da uomo Super Dark Black Lens...
# 2     grinderPUNCH  Occhiali da sole neri super scuri da uomo - st...
# 3     grinderPUNCH  Confezione da 2 occhiali da sole polarizzati d...
# 4            LINVO  Occhiali da Sole Polarizzati per Uomo Donna Pr...
# 5      Long Keeper  Occhiali da Sole Rettangolari Vintage Donna Ae...
# 6         Polaroid                              Occhiali da Sole Uomo
# 7          wearPro  Occhiali da sole pilota polarizzati per uomini...
# 8          Hawkers                          One Occhiali da Sole Uomo
# 9  Perfectmiaoxuan  Occhiali da sole polarizzati Avvolgente uomo d...
#
#                                              img_url  price  review_count  \
# 0  https://m.media-amazon.com/images/I/511UwgCobA...  19.99          3867
# 1  https://m.media-amazon.com/images/I/71yZOxJWmK...  19.99           263
# 2  https://m.media-amazon.com/images/I/712I90-woi...  19.99          1368
# 3  https://m.media-amazon.com/images/I/71D7cexzDU...  19.99          1533
# 4  https://m.media-amazon.com/images/I/41nt78vZ4o...  18.99          2086
# 5  https://m.media-amazon.com/images/I/51Y2bPPOEK...  13.97          3903
# 6  https://m.media-amazon.com/images/I/61j9TzijGC...  29.00           772
# 7  https://m.media-amazon.com/images/I/51BH+5wngj...   9.99          1085
# 8  https://m.media-amazon.com/images/I/51p-1sQOm7...  19.95         18557
# 9  https://m.media-amazon.com/images/I/718GME9KOA...  18.99           764
#
#    rating
# 0     4.1
# 1     4.5
# 2     4.1
# 3     4.1
# 4     4.3
# 5     4.2
# 6     4.2
# 7     4.3
# 8     4.4
# 9     4.2

# %% [markdown]
# ## 2.1 Download delle Immagini

# %%
import os

dest_dir = 'amazon_img'
os.makedirs(dest_dir, exist_ok=True)

# %%
import re  # libreria per le espressioni regolari
from os.path import join  # funzione per unire percorsi di directory
from urllib.request import urlretrieve as retrieve  # funzione per scaricare file da un URL

def download_images(data, dest_dir, fname="img_{id:05d}.{ext:s}"):
    data = data.copy()
    data['img_path'] = None  # Crea una nuova colonna 'img_path' nel DataFrame
    
    for i, row in data.iterrows():
        ext = re.search('[^.]+$', row['img_url']).group() # estensione
        fullpath = join(dest_dir, fname.format(id=int(row.name), ext=ext)) # percorso
        retrieve(row['img_url'], fullpath) # scarica l'immagine
        data.at[i, 'img_path'] = fullpath # Aggiungi il percorso al DataFrame usando 'at'

    return data

# %%
data2 = download_images(data, 'amazon_img')
data2
# Out:
#        manufacturer                                              model  \
# 0      grinderPUNCH  Occhiali da sole XL da uomo con montatura larg...
# 1      grinderPUNCH  Occhiali da sole da uomo Super Dark Black Lens...
# 2      grinderPUNCH  Occhiali da sole neri super scuri da uomo - st...
# 3      grinderPUNCH  Confezione da 2 occhiali da sole polarizzati d...
# 4             LINVO  Occhiali da Sole Polarizzati per Uomo Donna Pr...
# 5       Long Keeper  Occhiali da Sole Rettangolari Vintage Donna Ae...
# 6          Polaroid                              Occhiali da Sole Uomo
# 7           wearPro  Occhiali da sole pilota polarizzati per uomini...
# 8           Hawkers                          One Occhiali da Sole Uomo
# 9   Perfectmiaoxuan  Occhiali da sole polarizzati Avvolgente uomo d...
# 10          GOGELAS  Semi Rimless Occhiali da Sole per Uomini Donne...
# 17     4.4  amazon_img/img_00017.jpg
# 18     4.4  amazon_img/img_00018.jpg
# 19     4.2  amazon_img/img_00019.jpg
# 20     4.1  amazon_img/img_00020.jpg
# 21     4.3  amazon_img/img_00021.jpg
# 22     4.4  amazon_img/img_00022.jpg
# 23     4.3  amazon_img/img_00023.jpg
# 24     4.4  amazon_img/img_00024.jpg
# 25     4.0  amazon_img/img_00025.jpg
# 26     4.4  amazon_img/img_00026.jpg
# 27     4.4  amazon_img/img_00027.jpg
# 28     4.2  amazon_img/img_00028.jpg
# 29     4.4  amazon_img/img_00029.jpg
# 30     4.4  amazon_img/img_00030.jpg
# 31     4.0  amazon_img/img_00031.jpg
# 32     4.4  amazon_img/img_00032.jpg
# 33     5.0  amazon_img/img_00033.jpg
# 34     4.2  amazon_img/img_00034.jpg
# 35     3.9  amazon_img/img_00035.jpg
# 36     4.6  amazon_img/img_00036.jpg
# 37     4.2  amazon_img/img_00037.jpg
# 38     4.3  amazon_img/img_00038.jpg
# 39     4.4  amazon_img/img_00039.jpg
# 40     4.3  amazon_img/img_00040.jpg
# 41     4.4  amazon_img/img_00041.jpg
# 42     4.2  amazon_img/img_00042.jpg
# 43     4.4  amazon_img/img_00043.jpg
# 44     4.3  amazon_img/img_00044.jpg
# 45     4.4  amazon_img/img_00045.jpg
# 46     4.5  amazon_img/img_00046.jpg
# 47     4.4  amazon_img/img_00047.jpg
# 48     4.6  amazon_img/img_00048.jpg
# 49     4.3  amazon_img/img_00049.jpg
# 50     4.6  amazon_img/img_00050.jpg
# 51     4.0  amazon_img/img_00051.jpg
# 52     4.4  amazon_img/img_00052.jpg
# 53     4.1  amazon_img/img_00053.jpg
# 54     4.6  amazon_img/img_00054.jpg
# 55     4.3  amazon_img/img_00055.jpg
# 56     4.1  amazon_img/img_00056.jpg
# 57     3.0  amazon_img/img_00057.jpg
# 58     4.1  amazon_img/img_00058.jpg
# 59     4.3  amazon_img/img_00059.jpg

# %% [markdown]
# ## 2.2 Navigare Tra le Pagine

# %%
p = 1
part1_url = "https://www.amazon.it/s?k=occhiali+da+sole&page="
part2_url = "&crid=FY51CBDZSXMD&qid=1697798329&sprefix=%2Caps%2C106&ref=sr_pg_2"

def navigate_and_scrape(base_url, records = None):
    if records is None:
        records = []
    
    all_records = records
    page = 1 #iniziamo dalla pagina 1
    while(True):
        url = f"{part1_url}{p:d}{part2_url}"
        records = scrape_page(url)
        all_records.extend(records)
        if len(records)==0: #usciamo quando la pagina non contiene più record
            break
        page+=1
    
    return all_records

# %%
records = navigate_and_scrape(page_url)
data = pd.DataFrame(records, columns=['manufacturer','model','img_url','price','review_count','rating'])

# %%
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  480 non-null    object
#  1   model         480 non-null    object
#  2   img_url       480 non-null    object
#  3   price         480 non-null    float64
#  4   review_count  480 non-null    int64
#  5   rating        480 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 22.6+ KB
# None
#    manufacturer                                              model  \
# 0  grinderPUNCH  Occhiali da sole XL da uomo con montatura larg...
# 1  grinderPUNCH  Occhiali da sole da uomo Super Dark Black Lens...
# 2  grinderPUNCH  Occhiali da sole neri super scuri da uomo - st...
# 3  grinderPUNCH  Confezione da 2 occhiali da sole polarizzati d...
# 4         LINVO  Occhiali da Sole Polarizzati per Uomo Donna Pr...
#
#                                              img_url  price  review_count  \
# 0  https://m.media-amazon.com/images/I/511UwgCobA...  19.99          3867
# 1  https://m.media-amazon.com/images/I/71yZOxJWmK...  19.99           263
# 2  https://m.media-amazon.com/images/I/712I90-woi...  19.99          1368
# 3  https://m.media-amazon.com/images/I/71D7cexzDU...  19.99          1533
# 4  https://m.media-amazon.com/images/I/41nt78vZ4o...  18.99          2086
#
#    rating
# 0     4.1
# 1     4.5
# 2     4.1
# 3     4.1
# 4     4.3

# %% [markdown]
# ## 3 Analisi dei dati ottenuti

# %%
data.describe()
# Out:
#             price  review_count      rating
# count  480.000000    480.000000  480.000000
# mean    24.724375   2192.295833    4.152083
# std     17.153422   4644.407514    0.711401
# min      0.000000      0.000000    0.000000
# 25%     17.990000    263.000000    4.100000
# 50%     19.990000    672.000000    4.300000
# 75%     29.950000   2151.000000    4.400000
# max    152.670000  43616.000000    5.000000

# %%
from matplotlib import pyplot as plt # per la costruzione di grafici

# %% [markdown]
# #### Distribuzione percentuale dei produttori in base al numero di prodotti (quantità)

# %%
plt.figure(figsize=(8,8)) 
data.groupby('manufacturer')['manufacturer'].count().plot.pie(rotatelabels=True) # crea un grafico a torta 
#data['manufacturer'].value_counts().plot.pie(rotatelabels=True)
#data['manufacturer'].value_counts().plot.bar()
#data['manufacturer'].value_counts().plot.line()
#data.plot.scatter(x='price', y='rating')
#data.boxplot(column='price', by='manufacturer')
#data['price'].plot.hist()
#data.plot.area()
plt.show()

# %% [markdown]
# #### Media dei prezzi dei prodotti per ciascun produttore (costo)

# %%
plt.figure(figsize=(12,6))
data.groupby('manufacturer')['price'].mean().plot.bar() # crea un grafico a barre verticali
plt.grid()
plt.show()

# %% [markdown]
# #### Somma del numero di recensioni per ogni produttore (popolarità)

# %%
plt.figure(figsize=(12,6))
data.groupby('manufacturer')['review_count'].sum().plot.bar()
plt.grid()
plt.show()

# %% [markdown]
# #### Valutazioni (rating) medie dei prodotti in base ai produttori.

# %%
plt.figure(figsize=(12,6))
data.groupby('manufacturer')['rating'].mean().plot.bar()
plt.grid()
plt.show()

# %% [markdown]
# #### Media delle valutazioni per il produttore LOPKJ (valutazione media più bassa)

# %%
mask1 = data['manufacturer']=='LOPKJ'

plt.figure(figsize=(12,6))
data[mask1].groupby('manufacturer')['rating'].mean().plot.bar()
plt.grid()
plt.show()
