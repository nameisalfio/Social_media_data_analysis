# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="static/logo.png" width="120" height="120">
#     <h1>Tutorial API Web di Spotify</h1>
# </div>
#
# <p>
#     L'API Web Spotify consente la creazione di applicazioni in grado di interagire con il servizio di streaming di Spotify, ad esempio il recupero dei metadati dei contenuti, l'ottenimento di consigli, la creazione e la gestione di playlist o il controllo della riproduzione.
# </p>
#
# <h2>Indice</h2>
# <ol>
#     <li><a href="#preambolo">Preambolo</a></li>
#     <li><a href="#introduzione">Introduzione</a></li>
#     <li><a href="#profilo-e-applicazione">Profilo e applicazione</a></li>
#     <li><a href="#accesso-alle-api">Accesso alle API</a></li>
#     <li><a href="#utilizzo-delle-api-restful">Utilizzo delle API RESTful</a></li>
#     <li><a href="#api-spotify-python">API Spotify Python</a></li>
#     <li><a href="#estrazione-dati-e-analisi">Estrazione dati e analisi</a></li>
#     <li><a href="#conclusione">Conclusione</a></li>
# </ol>

# %% [markdown]
# <section id="preambolo">
#     <h2>1. Preambolo</h2>
#     <h3>Creare un ambiente virtuale</h3>
# </section>

# %% [markdown]
# Prima di iniziare, è consigliabile creare un ambiente virtuale per il tuo progetto.
# Puoi farlo utilizzando virtualenv o conda a seconda delle tue preferenze. Ecco un esempio utilizzando virtualenv:
#
# - Assicurati di avere virtualenv installato. Se non l'hai installato, puoi farlo utilizzando pip:

# %% [markdown]
# <code>pip install virtualenv</code>

# %% [markdown]
# - Scegli una directory in cui desideri creare il tuo ambiente virtuale. Naviga in quella directory tramite il terminale.
# - Crea un nuovo ambiente virtuale con il seguente comando:

# %% [markdown]
# <code>virtualenv nome_ambiente</code>

# %% [markdown]
# Sostituisci <span style="font-style: italic; font-size: 15px;"><i>"nome_ambiente"</i></span> con il nome che desideri dare al tuo ambiente virtuale.

# %% [markdown]
# - Attiva l'ambiente virtuale appena creato. Su sistemi Windows, usa il seguente comando:

# %% [markdown]
# <code>nome_ambiente\Scripts\activate</code>

# %% [markdown]
# Su sistemi Unix o macOS, usa:

# %% [markdown]
# <code>source nome_ambiente\bin\activate</code>

# %% [markdown]
# Per disattivare l'ambiente virtuale:

# %% [markdown]
# <code>deactivate</code>

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="static/Screen/Screen_1.png" width="900" height="600">
# </div>

# %% [markdown]
# Ora hai creato e attivato con successo un ambiente virtuale utilizzando virtualenv.<br>
# Puoi installare le librerie necessarie e lavorare sul tuo progetto all'interno di questo ambiente virtuale.

# %% [markdown]
# <section id="introduzione">
#     <h2>2. Introduzione</h2>
# </section>

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <h3>Prima di inizare... ma cos'è Spotify!?</h3>
#     <img src="static/emoji.png" width="80" height="80">
# </div>
# Spotify è una piattaforma di <strong>streaming musicale</strong> che offre agli utenti un vasto catalogo di brani musicali, podcast e altro ancora. Fondata nel 2006 in Svezia, Spotify ha rapidamente guadagnato popolarità in tutto il mondo come uno dei principali servizi di streaming musicale.
#
# Caratteristiche principali di Spotify:
# - <strong>Streaming Musicale:</strong> Gli utenti possono accedere a milioni di brani da artisti di tutto il mondo. La libreria musicale è vasta e copre una vasta gamma di generi e stili.
#
# - <strong>Playlist Personalizzate:</strong> Spotify offre funzionalità di raccomandazione avanzate che creano playlist personalizzate in base ai gusti musicali degli utenti. Queste playlist includono "Discover Weekly" e "Release Radar".
#
# - <strong>Podcast:</strong> Oltre alla musica, Spotify ospita una vasta gamma di podcast su argomenti che spaziano dalla cultura popolare alla scienza, dalla politica alla tecnologia.
#
# - <strong>Modalità Offline:</strong> Gli utenti possono scaricare brani e podcast per l'ascolto offline, ideale per chi vuole godersi la musica senza una connessione internet.
#
# - <strong>Condivisione Sociale:</strong> Spotify consente agli utenti di condividere le proprie playlist, brani preferiti e attività musicali su piattaforme di social media, consentendo una condivisione facile e interattiva.
#
# - <strong>Versatilità di Dispositivi:</strong> Spotify è accessibile su una vasta gamma di dispositivi, inclusi computer, smartphone, tablet, smart TV, console di gioco e altri dispositivi di streaming.

# %% [markdown]
# #### Descrizione generale di cosa sono le API di Spotify:
#
# Le <i><strong>API di Spotify</strong></i> sono strumenti che consentono agli sviluppatori di interagire con la piattaforma musicale di Spotify e accedere a diverse funzionalità.<br>
# Queste API forniscono un insieme di <strong>endpoint e metodi</strong> che consentono agli sviluppatori di recuperare informazioni sulle tracce, sugli artisti, sulle playlist
# e molto altro ancora. In sostanza, rappresentano un ponte che collega le potenzialità della piattaforma Spotify con le idee creative degli sviluppatori.

# %% [markdown]
# #### Importanza delle API per la creazione di app musicali:<br>
# Le <i><strong>API di Spotify</strong></i> sono fondamentali per la creazione di app musicali in quanto offrono agli sviluppatori l'accesso a un vasto catalogo musicale senza dover costruire tutto da zero. Questo non solo semplifica il processo di sviluppo, ma consente anche agli sviluppatori di concentrarsi sulla creatività e sull'innovazione, piuttosto che sulla gestione di database musicali complessi. Le API consentono inoltre di integrare funzionalità come la riproduzione di brani, la creazione di playlist personalizzate e molto altro, arricchendo l'esperienza dell'utente finale.

# %% [markdown]
# #### Anteprima delle Prossime Fasi:<br>
# Nelle prossime tappe del tutorial, esploreremo dettagliatamente le varie fasi necessarie per creare la tua app musicale utilizzando le API di Spotify. Partiremo con un'introduzione che getta le basi, passeremo poi alla creazione del profilo sviluppatore e alla registrazione dell'applicazione. Successivamente, affronteremo il cruciale processo di accesso alle API e impareremo come utilizzare le <strong>chiamate RESTful</strong> per ottenere informazioni musicali.<br>
#  Nel cuore del tutorial, ci immergeremo nell'utilizzo pratico delle API di Spotify con Python, aprendo un mondo di possibilità creative.<br>
#  Continueremo esplorando l'estrazione e l'analisi dei dati, per infine concludere il nostro viaggio con un riepilogo delle competenze acquisite e l'ispirazione per future esplorazioni.

# %% [markdown]
# <section id="profilo-e-applicazione">
#     <h2>3. Profilo e applicazione</h2>
# </section>

# %% [markdown]
# I seguenti passaggi ti guideranno nella creazione app musicali utilizzando l'API:
# <div class="container">
#     <p>Crea un'app e seleziona "API Web" quando ti chiede quali API hai intenzione di utilizzare.</p>
#     <a href="https://developer.spotify.com/documentation/web-api" target="_blank">
#         <button style="background-color: #1DB954; color: #fff; padding: 10px 15px; border: none; border-radius: 5px; cursor: pointer;">
#             Dashboard di Spotify Developer
#         </button>
#     </a>
# </div>

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="static/Screen/Screen_2.png" width="1200" height="800">
# </div>

# %% [markdown]
# Una volta creata l'applicazione risulterà consultabile nella Dashboard

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="static/Screen/Screen_3.png" width="1200" height="800">
# </div>

# %% [markdown]
# Una volta creata la tua app, avrai accesso alle credenziali dell'app. Questi saranno richiesti per l'autorizzazione API per ottenere un token di accesso .

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="static/Screen/Screen_4.png" width="1200" height="800">
# </div>

# %% [markdown]
# - Nella pagina delle impostazioni dell'app, aggiungi una <strong>Redirect URI</strong>. Questo è l'URL a cui Spotify reindirizzerà l'utente dopo l'autenticazione. <br>
# Puoi utilizzare http://localhost:5000/callback per scopi di sviluppo.

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="static/Screen/Screen_5.png" width="1200" height="600">
# </div>

# %% [markdown]
# <section id="accesso-alle-api">
#     <h2>4. Accesso alle API</h2>
# </section>

# %% [markdown]
# Le API di Spotify sono delle <strong> RESTful API</strong>. La loro implementazione segue lo stile architetturale REST, che si basa sul concetto di risorse identificate da URI e manipolate attraverso i metodi standard HTTP come GET, POST, PUT, DELETE, ecc.
#
# Il processo per ottenere il token di accesso da Spotify coinvolge la realizzazione di una richiesta POST all'endpoint https://accounts.spotify.com/api/token.
#
# Nel caso delle API REST di Spotify, la richiesta che abbiamo discusso in precedenza per ottenere il token di accesso utilizza il metodo POST per inviare dati al server di autorizzazione di Spotify. I parametri di autenticazione (client ID e client secret) vanno nell'header della richiesta, mentre i dettagli specifici della richiesta, come il tipo di concessione, vanno nel corpo della richiesta.
#
# ### Flusso di Autorizzazione OAuth 2.0:
#
# - Registrazione del Cliente:<br>Il cliente si registra presso l'Authorization Server, ottenendo un ID cliente e un segreto cliente.
#
# - Redirezione dell'Utente:<br>Il cliente reindirizza l'utente all'Authorization Server per l'autenticazione. In questo passo, il cliente può specificare il tipo di accesso richiesto (es. lettura o scrittura).
#
# - Concessione dell'Autorizzazione:<br>L'utente concede l'autorizzazione all'applicazione.
#
# - Ricezione del Codice di Autorizzazione:<br>L'Authorization Server reindirizza l'utente al client con un codice di autorizzazione.
#
# - Scambio del Codice per l'Access Token:<br>Il client invia il codice di autorizzazione all'Authorization Server per ottenere l'Access Token.
#
# - Utilizzo dell'Access Token:<br>Il client utilizza l'Access Token per accedere alle risorse protette presso il Resource Server.
#
# - Richiesta HTTP per l'Access Token:<br>Una richiesta POST all'endpoint dell'Authorization Server è coinvolta nella fase di scambio del codice per l'Access Token.

# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <img src="static/Screen/Screen_6.png" width="500" height="300">
# </div>

# %% [markdown]
# Scriviamo quindi una funzione in <strong>Python</strong> che può essere utilizzata per ottenere un token di accesso valido, che verra poi utilizzato per <strong>autenticare le richieste alle API</strong> di Spotify.

# %%
def get_spotify_access_token(client_id, client_secret):
    url = 'https://accounts.spotify.com/api/token'
    headers = {
        'Authorization': 'Basic ' + base64.b64encode(f'{client_id}:{client_secret}'.encode()).decode()
    }
    data = {
        'grant_type': 'client_credentials'
    }
    
    try:
        response = requests.post(url, headers=headers, data=data)
        response.raise_for_status()  # Solleva un'eccezione se la richiesta HTTP non ha successo
        token_data = response.json()
        
        if 'access_token' in token_data:
            return token_data['access_token']
        else:
            raise Exception(f"Errore nell'ottenere il token di accesso: {token_data.get('error', 'Errore sconosciuto')}")
            
    except requests.exceptions.RequestException as e:
        raise Exception(f"Errore nella richiesta HTTP: {e}")

# %% [markdown]
# Adesso verifichiamo il corretto ottenimento del Token di accesso

# %%
import requests
import base64

client_id = 'cd0f7e9279034469a5c4560808cb31a8' 
client_secret = 'da3fe74efc5c4a84b71399c157366e09'
access_token = get_spotify_access_token(client_id, client_secret) # ottengo il token di accesso

print(f"Token di accesso: {access_token}")
# Out:
# Token di accesso: BQCXrFrpQAbFfiWVFEUZCZMnnhXeUkv7_Sseq6Vc3Rzgnlqu0g2Fbm05hrICXVVerh-m63tQ5x-3mfBo7KO-byoWYTetVl4tn6RcBuHsvaIEM1DRHfE

# %% [markdown]
# <section id="utilizzo-delle-api-restful">
#     <h2>5. Utilizzo delle API RESTful</h2>
# </section>

# %% [markdown]
# Una volta acquisito il token di accesso, siamo pronti per autenticare e autorizzare le richieste alle API. Probabilmente la prima cosa che si può pensare di voler fare attraverso un'interfaccia di programmazione simile è proprio andare a ricercare un determinato artista su spotify in modo da ottenere tutte le sue informazioni:
#
# - Nome
# - ID
# - Genere
# - Popolarità
# - Followers
# - URL di Spotify
# - Immagine profilo

# %%
def search_artist(token, artist_name):
    url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "q": artist_name,
        "type": "artist",
        "limit": 1
    }
    
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()  # Solleva un'eccezione se la richiesta HTTP non ha successo
        data = response.json()
        artists = data.get("artists", {}).get("items", [])
        
        if artists:
            return artists[0]
        else:
            print(f"Nessun artista trovato con il nome '{artist_name}'.")
            return None
            
    except requests.exceptions.RequestException as e:
        print(f"Errore nella richiesta HTTP: {e}")
        return None

# %% [markdown]
# Può essere utile scrivere anche delle funzioni ausiliarie per:
# - estrarre il link a Spotify dal dizionario <strong>"external_urls"</strong> dell'entità;
# - renderlo accessibile tramite un semplice click, in modo da ridirezionare alla pagina specificata dall'url;
# - mostrare le varie immagini a partire dal loro url;
# - convertire le durate (in ms) dei brani in minuti;

# %%
def extract_spotify_url(external_urls):
    return external_urls['spotify']
    
def make_clickable(link):
    return f'<a href="{link}" target="_blank">{link}</a>'

def display_image(image_url):
    return f'<img src="{image_url}" alt="Cover Image" style="max-height: 80px; max-width: 80px;">'

def convert_duration(duration_ms):
    duration_minutes = duration_ms / 60000
    return round(duration_minutes, 2)

# %%
import pandas as pd
from IPython.display import Image, display, HTML

artist_name = "Emis Killa" 
artist = search_artist(access_token, artist_name) # ottengo l'artista

artist_data = {
    "Nome": artist["name"],
    "ID": artist["id"] ,
    "Genere": artist["genres"][0],
    "Popolarità": artist["popularity"],
    "Followers": artist["followers"]["total"],
    "Spotify URL": artist["external_urls"]["spotify"],
    "Immagine": artist["images"][0]["url"]
}

pd.set_option('display.max_colwidth', 1)
artist_data_frame = pd.DataFrame([artist_data])
artist_data_frame['Spotify URL'] = artist_data_frame['Spotify URL'].apply(make_clickable)
artist_data_frame['Immagine'] = artist_data_frame['Immagine'].apply(display_image)

print(f"Artista trovato: {artist_name} (ID: {artist_data['ID']})\n") 
HTML(artist_data_frame.to_html(escape=False))
# Out:
# Artista trovato: Emis Killa (ID: 6FtwCmLY6L1sqvjaQ2lV6G)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nome</th>
#       <th>ID</th>
#       <th>Genere</th>
#       <th>Popolarità</th>
#       <th>Followers</th>
#       <th>Spotify URL</th>
#       <th>Immagine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Emis Killa</td>
#       <td>6FtwCmLY6L1sqvjaQ2lV6G</td>
#       <td>italian hip hop</td>
#       <td>62</td>
#       <td>1547442</td>
#       <td><a href="https://open.spotify.com/artist/6FtwCmLY6L1sqvjaQ2lV6G" target="_blank">https://open.spotify.com/artist/6FtwCmLY6L1sqvjaQ2lV6G</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb51507026f810de5f84d9e8a2" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Nei prossimi paragrafi, approfondiremo l'utilizzo delle strutture dati in Python, in particolare i DataFrame di Pandas, per un'analisi dettagliata dei contenuti di Spotify.
#
# Utilizzeremo queste potenti strutture dati per:
#
# - Estrarre dati dettagliati su brani, artisti e album.
# - Manipolare le informazioni in modi avanzati.
# - Visualizzare in modo chiaro e comprensibile le tendenze e le relazioni presenti nelle informazioni di Spotify.
#
# Inizieremo con l'analisi delle top chart degli artisti, per poi esplorare le caratteristiche dei brani più popolari, ottenere dettagli sugli album e presentare statistiche di ascolto degli utenti. Sfrutteremo appieno le potenzialità delle librerie Python e delle API di Spotify per un'analisi completa e informativa.

# %% [markdown]
# <section id="api-spotify-python">
#     <h2>6. API Spotify Python</h2>
# </section>

# %% [markdown]
# Risulta interessante anche chiedersi quali sono gli album dell'artista appena trovato. Anche questo può essere facilmente ottenuto grazzie all'uso delle API di Spotify, a partire dall'id dell'artista. In particolare prenderemo le informazioni rigurdanti :
#
# - Nome
# - ID
# - Data di uscita
# - Numero totale di tracce
# - Immagine di copertina
# - URL di Spotify

# %%
def get_albums(token, artist_id):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "market": "IT"
    }

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()  # Solleva un'eccezione se la richiesta HTTP non ha successo
        data = response.json()
        
        return data.get("items", [])
        
    except requests.exceptions.RequestException as e:
        print(f"Errore nella richiesta HTTP: {e}")
        return []

# %%
artist_albums = get_albums(access_token, artist["id"])
album_data_frame = pd.DataFrame(artist_albums, columns=['name', 'id', 'release_date', 'total_tracks', 'images', 'external_urls'])

# Rinomina le colonne per chiarezza
album_data_frame = album_data_frame.rename(columns={'name': 'Titolo', 'id': 'ID', 'release_date': 'Data di uscita', 'total_tracks': 'No. Tracce', 'images': 'Copertina', 'external_urls': 'Spotify URL'})

# Visualizza l'immagine dell'album
album_data_frame['Copertina'] = album_data_frame['Copertina'].apply(lambda x: display_image(x[0]["url"]))

# Filtra gli album con un numero diverso da 1 di tracce
album_data_frame = album_data_frame[album_data_frame["No. Tracce"] != 1]

# Rendi cliccabili gli URL di Spotify
album_data_frame['Spotify URL'] = album_data_frame['Spotify URL'].apply(extract_spotify_url)
album_data_frame['Spotify URL'] = album_data_frame['Spotify URL'].apply(make_clickable)

print(f"Gli album dell'artista {artist_name} sono:\n")
display(HTML(album_data_frame.to_html(escape=False)))
# Out:
# Gli album dell'artista Emis Killa sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Data di uscita</th>
#       <th>No. Tracce</th>
#       <th>Copertina</th>
#       <th>Spotify URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Effetto notte</td>
#       <td>39wuRno08Rl0Jsse2kCHga</td>
#       <td>2023-05-19</td>
#       <td>14</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b27329df67b7e1d45411f2ac4a92" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/39wuRno08Rl0Jsse2kCHga" target="_blank">https://open.spotify.com/album/39wuRno08Rl0Jsse2kCHga</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#       <td>53qzcXW1K4TdnJZUp0Ftpu</td>
#       <td>2022-12-09</td>
#       <td>15</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273242a0776336907836334029c" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/53qzcXW1K4TdnJZUp0Ftpu" target="_blank">https://open.spotify.com/album/53qzcXW1K4TdnJZUp0Ftpu</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Keta Music, Vol. 3</td>
#       <td>5XmLyPktaR9fYxYqtQukqa</td>
#       <td>2021-07-23</td>
#       <td>11</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b27361a8db9d4b70277fd4de59eb" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/5XmLyPktaR9fYxYqtQukqa" target="_blank">https://open.spotify.com/album/5XmLyPktaR9fYxYqtQukqa</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17 - Dark Edition</td>
#       <td>6nKQCH9bP1APHf83iDCjO2</td>
#       <td>2021-02-26</td>
#       <td>24</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273b9f08f2cfa7b46aa699a2077" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/6nKQCH9bP1APHf83iDCjO2" target="_blank">https://open.spotify.com/album/6nKQCH9bP1APHf83iDCjO2</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17</td>
#       <td>11T8pkk7VAT7LeoReyY7B7</td>
#       <td>2020-09-18</td>
#       <td>17</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b27340039bd30ffcd9f3ecdf8069" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/11T8pkk7VAT7LeoReyY7B7" target="_blank">https://open.spotify.com/album/11T8pkk7VAT7LeoReyY7B7</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Supereroe Bat Edition</td>
#       <td>3YdgMr7sbDBeuPotzWJz60</td>
#       <td>2019-06-21</td>
#       <td>17</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273ab2a312a1c11cb2a39159f54" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/3YdgMr7sbDBeuPotzWJz60" target="_blank">https://open.spotify.com/album/3YdgMr7sbDBeuPotzWJz60</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Supereroe</td>
#       <td>67g3eUjlYFB7EkhS1pjKe4</td>
#       <td>2018-10-12</td>
#       <td>13</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273402bbf743838dd9f7f0fa376" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/67g3eUjlYFB7EkhS1pjKe4" target="_blank">https://open.spotify.com/album/67g3eUjlYFB7EkhS1pjKe4</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Terza Stagione</td>
#       <td>2goDKoHetJSDYCxZq9h17h</td>
#       <td>2016-10-14</td>
#       <td>17</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273d4925a77400252d9922419f9" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/2goDKoHetJSDYCxZq9h17h" target="_blank">https://open.spotify.com/album/2goDKoHetJSDYCxZq9h17h</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Keta Music - Volume 2</td>
#       <td>2P8Ga6LVlc6lwuKwxsrbsd</td>
#       <td>2015-06-18</td>
#       <td>13</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b2739d9a7d9b30780cc832b3b5f2" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/2P8Ga6LVlc6lwuKwxsrbsd" target="_blank">https://open.spotify.com/album/2P8Ga6LVlc6lwuKwxsrbsd</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Mercurio - 5 Stars Edition</td>
#       <td>5ZPw8Dc0rcfLBlJj9zJ9pK</td>
#       <td>2014-06-10</td>
#       <td>19</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273b9eece34c479260d347da140" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/5ZPw8Dc0rcfLBlJj9zJ9pK" target="_blank">https://open.spotify.com/album/5ZPw8Dc0rcfLBlJj9zJ9pK</a></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Mercurio</td>
#       <td>3pXSt0UQJINOx5GP6NORLj</td>
#       <td>2013-10-22</td>
#       <td>16</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273b449e1b8feab3963573516fd" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/3pXSt0UQJINOx5GP6NORLj" target="_blank">https://open.spotify.com/album/3pXSt0UQJINOx5GP6NORLj</a></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>L'erba cattiva (Gold Edition)</td>
#       <td>4Ol0xyGSCkq7Zv1JNcX7Rg</td>
#       <td>2012-11-20</td>
#       <td>17</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273968cd5e6ac49657f28d994cf" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/4Ol0xyGSCkq7Zv1JNcX7Rg" target="_blank">https://open.spotify.com/album/4Ol0xyGSCkq7Zv1JNcX7Rg</a></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>L'erba cattiva</td>
#       <td>2Dbxqy0O665QXENEoKc1oH</td>
#       <td>2012-02-07</td>
#       <td>15</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273343ada3f2f036a4979857eec" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/2Dbxqy0O665QXENEoKc1oH" target="_blank">https://open.spotify.com/album/2Dbxqy0O665QXENEoKc1oH</a></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Il peggiore</td>
#       <td>31riS17FsOEsxeEktZtUHf</td>
#       <td>2011-12-19</td>
#       <td>7</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273f3286dd229e718c781a4c349" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/31riS17FsOEsxeEktZtUHf" target="_blank">https://open.spotify.com/album/31riS17FsOEsxeEktZtUHf</a></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Champagne e spine</td>
#       <td>2yN0GHM0z6tWAhDUvX3gr3</td>
#       <td>2010</td>
#       <td>19</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b2731d43e2da550d29b91da6fb35" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#       <td><a href="https://open.spotify.com/album/2yN0GHM0z6tWAhDUvX3gr3" target="_blank">https://open.spotify.com/album/2yN0GHM0z6tWAhDUvX3gr3</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Adesso che abbiamo ottenuto la discografia dell'artista, possiamo esaminare anche il contenuto dei suoi album.<br>
# Possiamo esaminare un album in particolare specificandone l'ID ma risulta pià interessante esaminare l'intera discografia dell'artista.
#
# Per ogni brano in particolare siamo interessati a :
#
# - Titolo
# - ID
# - Data di uscita
# - Numero totale di tracce
# - Immagine di copertina
# - Spotify URL

# %%
def get_album_tracks(token, album_id):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "market": "IT"
    }

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()  # Solleva un'eccezione se la richiesta HTTP non ha successo
        data = response.json()
        
        return data.get("items", [])
        
    except requests.exceptions.RequestException as e:
        print(f"Errore nella richiesta HTTP: {e}")
        return []

# %%
album_name = "Effetto notte"  
album_id = album_data_frame.loc[album_data_frame['Titolo'] == album_name, 'ID'].values[0]

album_tracks = get_album_tracks(access_token, album_id)
tracks_data_frame = pd.DataFrame(album_tracks, columns=['name','id','duration_ms','external_urls'])
tracks_data_frame = tracks_data_frame.rename(columns={'name': 'Titolo', 'id': 'ID', 'duration_ms': 'Durata', 'external_urls': 'Spotify URL'})

tracks_data_frame['Durata'] = tracks_data_frame['Durata'].apply(convert_duration)
tracks_data_frame['Spotify URL'] = tracks_data_frame['Spotify URL'].apply(extract_spotify_url)
tracks_data_frame['Spotify URL'] = tracks_data_frame['Spotify URL'].apply(make_clickable)

print(f"Le tracce dell'album {album_name} sono:\n")
display(HTML(tracks_data_frame.to_html(escape=False)))
# Out:
# Le tracce dell'album Effetto notte sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PACINO - the godfather</td>
#       <td>0DJJkaSRugtaqVjWOItGn0</td>
#       <td>2.04</td>
#       <td><a href="https://open.spotify.com/track/0DJJkaSRugtaqVjWOItGn0" target="_blank">https://open.spotify.com/track/0DJJkaSRugtaqVjWOItGn0</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ON FIRE - paid in full</td>
#       <td>2pGbOFiWVwZaTq3iKi5sGb</td>
#       <td>2.93</td>
#       <td><a href="https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb" target="_blank">https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>COL CUORE IN GOLA - lords of dogtown</td>
#       <td>2ypcWaliFPJ9c3JeWMqi1w</td>
#       <td>3.14</td>
#       <td><a href="https://open.spotify.com/track/2ypcWaliFPJ9c3JeWMqi1w" target="_blank">https://open.spotify.com/track/2ypcWaliFPJ9c3JeWMqi1w</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>VISCERALE - closer</td>
#       <td>7bgJm5Z7EpvXRMdysiUjCj</td>
#       <td>3.07</td>
#       <td><a href="https://open.spotify.com/track/7bgJm5Z7EpvXRMdysiUjCj" target="_blank">https://open.spotify.com/track/7bgJm5Z7EpvXRMdysiUjCj</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>MASERATI - the wolf of wall street</td>
#       <td>3vZ3ZCdyr7jxBDKzgFtKBN</td>
#       <td>2.27</td>
#       <td><a href="https://open.spotify.com/track/3vZ3ZCdyr7jxBDKzgFtKBN" target="_blank">https://open.spotify.com/track/3vZ3ZCdyr7jxBDKzgFtKBN</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>LONTANO - carlito's way</td>
#       <td>2t1dculU2L9HxEIzB00Xpk</td>
#       <td>2.78</td>
#       <td><a href="https://open.spotify.com/track/2t1dculU2L9HxEIzB00Xpk" target="_blank">https://open.spotify.com/track/2t1dculU2L9HxEIzB00Xpk</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ALBICOCCA - lolita</td>
#       <td>1Bkq1PP6QZrZcpAyEnIKDy</td>
#       <td>2.71</td>
#       <td><a href="https://open.spotify.com/track/1Bkq1PP6QZrZcpAyEnIKDy" target="_blank">https://open.spotify.com/track/1Bkq1PP6QZrZcpAyEnIKDy</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BIG BANG - upside down</td>
#       <td>6IMdD50UNZOZxGro2bgsnN</td>
#       <td>3.30</td>
#       <td><a href="https://open.spotify.com/track/6IMdD50UNZOZxGro2bgsnN" target="_blank">https://open.spotify.com/track/6IMdD50UNZOZxGro2bgsnN</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>TOXIC - trainspotting</td>
#       <td>3mrtP5imQ3Mv3OQ0byI4ix</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/3mrtP5imQ3Mv3OQ0byI4ix" target="_blank">https://open.spotify.com/track/3mrtP5imQ3Mv3OQ0byI4ix</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>SONNY - city of god</td>
#       <td>3knzVyYsKLWzlzdBiZPHWB</td>
#       <td>3.18</td>
#       <td><a href="https://open.spotify.com/track/3knzVyYsKLWzlzdBiZPHWB" target="_blank">https://open.spotify.com/track/3knzVyYsKLWzlzdBiZPHWB</a></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>MC DRIVE - la haine</td>
#       <td>6xEKlNQQ5XcUXihEQ6wON7</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/6xEKlNQQ5XcUXihEQ6wON7" target="_blank">https://open.spotify.com/track/6xEKlNQQ5XcUXihEQ6wON7</a></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>SENZ'ANIMA - nikita</td>
#       <td>39ZJEJ8KLq8yQQ1OEAdJ1W</td>
#       <td>3.22</td>
#       <td><a href="https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W" target="_blank">https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W</a></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>ATTORI DI STRADA - ragazzi fuori</td>
#       <td>1VTZiz4hE2YSaJZZ83N5dr</td>
#       <td>3.51</td>
#       <td><a href="https://open.spotify.com/track/1VTZiz4hE2YSaJZZ83N5dr" target="_blank">https://open.spotify.com/track/1VTZiz4hE2YSaJZZ83N5dr</a></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>BEL FINALE - the butterfly effect</td>
#       <td>36IxxPEiwxT1TPRDsKXdxY</td>
#       <td>1.86</td>
#       <td><a href="https://open.spotify.com/track/36IxxPEiwxT1TPRDsKXdxY" target="_blank">https://open.spotify.com/track/36IxxPEiwxT1TPRDsKXdxY</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Si nota che durante l'iterazione su ogni brano di ogni album, viene inserita ogni traccia in un dataframe complessivo.
# #### Questo ci sarà utile quando faremo statistiche nella <strong>sezione 7 del tutorial</strong>.
# - Ci server anche una funzione che renda cliccabili gli URL del dataframe globale :

# %%
from bs4 import BeautifulSoup

def extract_href(html):
    soup = BeautifulSoup(html, 'html.parser')
    return soup.a['href']

# %%
# Creazione del DataFrame complessivo utile per la sezione 7 del tutorial
discography_data_frames_list = []

for index, row in album_data_frame.iterrows():
    album_name = row['Titolo']
    album_id = row['ID']

    album_tracks = get_album_tracks(access_token, album_id)

    tracks_data_frame = pd.DataFrame(album_tracks, columns=['name', 'id', 'duration_ms', 'external_urls'])
    tracks_data_frame = tracks_data_frame.rename(columns={'name': 'Titolo', 'id': 'ID', 'duration_ms': 'Durata', 'external_urls': 'Spotify URL'})

    tracks_data_frame['Durata'] = tracks_data_frame['Durata'].apply(convert_duration)

    tracks_data_frame['Spotify URL'] = tracks_data_frame['Spotify URL'].apply(extract_spotify_url)
    tracks_data_frame['Spotify URL'] = tracks_data_frame['Spotify URL'].apply(make_clickable)
    
    tracks_data_frame['Album'] = album_name
    discography_data_frames_list.append(tracks_data_frame)

    print(f"\nLe tracce dell'album \"{album_name}\" sono:\n")
    display(HTML(tracks_data_frame.to_html(escape=False)))
    print('=' * 138)

discography_data_frame = pd.concat(discography_data_frames_list, ignore_index=True)
discography_data_frame['Spotify URL'] = discography_data_frame['Spotify URL'].apply(extract_href)
discography_data_frame['Spotify URL'] = discography_data_frame['Spotify URL'].apply(make_clickable)
# Out:
# Le tracce dell'album "Effetto notte" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PACINO - the godfather</td>
#       <td>0DJJkaSRugtaqVjWOItGn0</td>
#       <td>2.04</td>
#       <td><a href="https://open.spotify.com/track/0DJJkaSRugtaqVjWOItGn0" target="_blank">https://open.spotify.com/track/0DJJkaSRugtaqVjWOItGn0</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ON FIRE - paid in full</td>
#       <td>2pGbOFiWVwZaTq3iKi5sGb</td>
#       <td>2.93</td>
#       <td><a href="https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb" target="_blank">https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>COL CUORE IN GOLA - lords of dogtown</td>
#       <td>2ypcWaliFPJ9c3JeWMqi1w</td>
#       <td>3.14</td>
#       <td><a href="https://open.spotify.com/track/2ypcWaliFPJ9c3JeWMqi1w" target="_blank">https://open.spotify.com/track/2ypcWaliFPJ9c3JeWMqi1w</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>VISCERALE - closer</td>
#       <td>7bgJm5Z7EpvXRMdysiUjCj</td>
#       <td>3.07</td>
#       <td><a href="https://open.spotify.com/track/7bgJm5Z7EpvXRMdysiUjCj" target="_blank">https://open.spotify.com/track/7bgJm5Z7EpvXRMdysiUjCj</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>MASERATI - the wolf of wall street</td>
#       <td>3vZ3ZCdyr7jxBDKzgFtKBN</td>
#       <td>2.27</td>
#       <td><a href="https://open.spotify.com/track/3vZ3ZCdyr7jxBDKzgFtKBN" target="_blank">https://open.spotify.com/track/3vZ3ZCdyr7jxBDKzgFtKBN</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>LONTANO - carlito's way</td>
#       <td>2t1dculU2L9HxEIzB00Xpk</td>
#       <td>2.78</td>
#       <td><a href="https://open.spotify.com/track/2t1dculU2L9HxEIzB00Xpk" target="_blank">https://open.spotify.com/track/2t1dculU2L9HxEIzB00Xpk</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ALBICOCCA - lolita</td>
#       <td>1Bkq1PP6QZrZcpAyEnIKDy</td>
#       <td>2.71</td>
#       <td><a href="https://open.spotify.com/track/1Bkq1PP6QZrZcpAyEnIKDy" target="_blank">https://open.spotify.com/track/1Bkq1PP6QZrZcpAyEnIKDy</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BIG BANG - upside down</td>
#       <td>6IMdD50UNZOZxGro2bgsnN</td>
#       <td>3.30</td>
#       <td><a href="https://open.spotify.com/track/6IMdD50UNZOZxGro2bgsnN" target="_blank">https://open.spotify.com/track/6IMdD50UNZOZxGro2bgsnN</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>TOXIC - trainspotting</td>
#       <td>3mrtP5imQ3Mv3OQ0byI4ix</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/3mrtP5imQ3Mv3OQ0byI4ix" target="_blank">https://open.spotify.com/track/3mrtP5imQ3Mv3OQ0byI4ix</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>SONNY - city of god</td>
#       <td>3knzVyYsKLWzlzdBiZPHWB</td>
#       <td>3.18</td>
#       <td><a href="https://open.spotify.com/track/3knzVyYsKLWzlzdBiZPHWB" target="_blank">https://open.spotify.com/track/3knzVyYsKLWzlzdBiZPHWB</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>MC DRIVE - la haine</td>
#       <td>6xEKlNQQ5XcUXihEQ6wON7</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/6xEKlNQQ5XcUXihEQ6wON7" target="_blank">https://open.spotify.com/track/6xEKlNQQ5XcUXihEQ6wON7</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>SENZ'ANIMA - nikita</td>
#       <td>39ZJEJ8KLq8yQQ1OEAdJ1W</td>
#       <td>3.22</td>
#       <td><a href="https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W" target="_blank">https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>ATTORI DI STRADA - ragazzi fuori</td>
#       <td>1VTZiz4hE2YSaJZZ83N5dr</td>
#       <td>3.51</td>
#       <td><a href="https://open.spotify.com/track/1VTZiz4hE2YSaJZZ83N5dr" target="_blank">https://open.spotify.com/track/1VTZiz4hE2YSaJZZ83N5dr</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>BEL FINALE - the butterfly effect</td>
#       <td>36IxxPEiwxT1TPRDsKXdxY</td>
#       <td>1.86</td>
#       <td><a href="https://open.spotify.com/track/36IxxPEiwxT1TPRDsKXdxY" target="_blank">https://open.spotify.com/track/36IxxPEiwxT1TPRDsKXdxY</a></td>
#       <td>Effetto notte</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "L'erba cattiva (10 Years Anniversary Edition)" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sulla luna (intro)</td>
#       <td>3nKA4HNuLw8oRvjBjY116r</td>
#       <td>2.09</td>
#       <td><a href="https://open.spotify.com/track/3nKA4HNuLw8oRvjBjY116r" target="_blank">https://open.spotify.com/track/3nKA4HNuLw8oRvjBjY116r</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Cashwoman</td>
#       <td>3diNNevWuOFP00rJs51EcF</td>
#       <td>2.79</td>
#       <td><a href="https://open.spotify.com/track/3diNNevWuOFP00rJs51EcF" target="_blank">https://open.spotify.com/track/3diNNevWuOFP00rJs51EcF</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Parole di ghiaccio</td>
#       <td>3IR20zWyql3UyURiPs5RaB</td>
#       <td>3.73</td>
#       <td><a href="https://open.spotify.com/track/3IR20zWyql3UyURiPs5RaB" target="_blank">https://open.spotify.com/track/3IR20zWyql3UyURiPs5RaB</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Dietro front (feat. Fabri Fibra)</td>
#       <td>7h92cTYpnRSYpV25sixGlm</td>
#       <td>3.10</td>
#       <td><a href="https://open.spotify.com/track/7h92cTYpnRSYpV25sixGlm" target="_blank">https://open.spotify.com/track/7h92cTYpnRSYpV25sixGlm</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Come un pitbull</td>
#       <td>0VeRBqohOzb3nF8KhYQwEK</td>
#       <td>3.63</td>
#       <td><a href="https://open.spotify.com/track/0VeRBqohOzb3nF8KhYQwEK" target="_blank">https://open.spotify.com/track/0VeRBqohOzb3nF8KhYQwEK</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Ognuno per sè (feat. Guè)</td>
#       <td>1pegcvjD0vrZrHUOmiifUA</td>
#       <td>3.14</td>
#       <td><a href="https://open.spotify.com/track/1pegcvjD0vrZrHUOmiifUA" target="_blank">https://open.spotify.com/track/1pegcvjD0vrZrHUOmiifUA</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>L'erba cattiva</td>
#       <td>4hoyFHWi1812CUl4FCFVXt</td>
#       <td>3.81</td>
#       <td><a href="https://open.spotify.com/track/4hoyFHWi1812CUl4FCFVXt" target="_blank">https://open.spotify.com/track/4hoyFHWi1812CUl4FCFVXt</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Cocktailz (feat. G. Soave & Duellz)</td>
#       <td>3k3LP2DUyT9mDhaaZNcob9</td>
#       <td>3.41</td>
#       <td><a href="https://open.spotify.com/track/3k3LP2DUyT9mDhaaZNcob9" target="_blank">https://open.spotify.com/track/3k3LP2DUyT9mDhaaZNcob9</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Nice pic</td>
#       <td>6xb8eMUgjdELMBcNM96va4</td>
#       <td>3.09</td>
#       <td><a href="https://open.spotify.com/track/6xb8eMUgjdELMBcNM96va4" target="_blank">https://open.spotify.com/track/6xb8eMUgjdELMBcNM96va4</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Nei guai (feat. Tormento)</td>
#       <td>2CGvZZnXy6TfrJ4PBKdK86</td>
#       <td>3.15</td>
#       <td><a href="https://open.spotify.com/track/2CGvZZnXy6TfrJ4PBKdK86" target="_blank">https://open.spotify.com/track/2CGvZZnXy6TfrJ4PBKdK86</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Giusto o sbagliato</td>
#       <td>4ve1unJ2E520POuHUU7654</td>
#       <td>3.15</td>
#       <td><a href="https://open.spotify.com/track/4ve1unJ2E520POuHUU7654" target="_blank">https://open.spotify.com/track/4ve1unJ2E520POuHUU7654</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Il mondo dei grandi (feat. Marracash)</td>
#       <td>3hBnQj5DVAtVJNELFf76nY</td>
#       <td>3.76</td>
#       <td><a href="https://open.spotify.com/track/3hBnQj5DVAtVJNELFf76nY" target="_blank">https://open.spotify.com/track/3hBnQj5DVAtVJNELFf76nY</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Tutto quello che ho (feat. Fabio De Martino)</td>
#       <td>3JhTUTLtKUQh5bYmok1xHd</td>
#       <td>4.62</td>
#       <td><a href="https://open.spotify.com/track/3JhTUTLtKUQh5bYmok1xHd" target="_blank">https://open.spotify.com/track/3JhTUTLtKUQh5bYmok1xHd</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Il peggiore</td>
#       <td>7LWFSqziGBYESZBn0IUowP</td>
#       <td>3.44</td>
#       <td><a href="https://open.spotify.com/track/7LWFSqziGBYESZBn0IUowP" target="_blank">https://open.spotify.com/track/7LWFSqziGBYESZBn0IUowP</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Di.Enne.A.</td>
#       <td>6gAaLEX4dEAKNlyiysstms</td>
#       <td>4.23</td>
#       <td><a href="https://open.spotify.com/track/6gAaLEX4dEAKNlyiysstms" target="_blank">https://open.spotify.com/track/6gAaLEX4dEAKNlyiysstms</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Keta Music, Vol. 3" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Qualche sasso</td>
#       <td>0ON7cT98E4H7Rh4dzfvKCa</td>
#       <td>2.13</td>
#       <td><a href="https://open.spotify.com/track/0ON7cT98E4H7Rh4dzfvKCa" target="_blank">https://open.spotify.com/track/0ON7cT98E4H7Rh4dzfvKCa</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>No police no problem (feat. J. Lord)</td>
#       <td>4VrigPWWuXhToLQnHEaaXf</td>
#       <td>2.44</td>
#       <td><a href="https://open.spotify.com/track/4VrigPWWuXhToLQnHEaaXf" target="_blank">https://open.spotify.com/track/4VrigPWWuXhToLQnHEaaXf</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Morto di fame (feat. Lazza)</td>
#       <td>4hqi818jHZUJIbJ6OJllGI</td>
#       <td>2.72</td>
#       <td><a href="https://open.spotify.com/track/4hqi818jHZUJIbJ6OJllGI" target="_blank">https://open.spotify.com/track/4hqi818jHZUJIbJ6OJllGI</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Psycho (feat. Rose Villain)</td>
#       <td>1T0Yxsej1IIwR9Zxx676da</td>
#       <td>2.38</td>
#       <td><a href="https://open.spotify.com/track/1T0Yxsej1IIwR9Zxx676da" target="_blank">https://open.spotify.com/track/1T0Yxsej1IIwR9Zxx676da</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Notte gialla (feat. Madame)</td>
#       <td>5KkH1w1g6ACMRoz1fYvWCb</td>
#       <td>3.18</td>
#       <td><a href="https://open.spotify.com/track/5KkH1w1g6ACMRoz1fYvWCb" target="_blank">https://open.spotify.com/track/5KkH1w1g6ACMRoz1fYvWCb</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Jam session (feat. Gemitaiz)</td>
#       <td>4TN1OPvUjXlFlgSZts4uus</td>
#       <td>2.82</td>
#       <td><a href="https://open.spotify.com/track/4TN1OPvUjXlFlgSZts4uus" target="_blank">https://open.spotify.com/track/4TN1OPvUjXlFlgSZts4uus</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>I soldi degli altri (feat. Jake La Furia & Montenero)</td>
#       <td>2ll2BFFW0QbQJ5MGhAXZr2</td>
#       <td>2.94</td>
#       <td><a href="https://open.spotify.com/track/2ll2BFFW0QbQJ5MGhAXZr2" target="_blank">https://open.spotify.com/track/2ll2BFFW0QbQJ5MGhAXZr2</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Street Movie (feat. Jake La Furia & RollzRois)</td>
#       <td>56i2Lo76YMcsJt1daDxSbJ</td>
#       <td>2.78</td>
#       <td><a href="https://open.spotify.com/track/56i2Lo76YMcsJt1daDxSbJ" target="_blank">https://open.spotify.com/track/56i2Lo76YMcsJt1daDxSbJ</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Piede in strada (feat. Mera)</td>
#       <td>58oeJn3WUNbOBwaDFLgYL3</td>
#       <td>2.67</td>
#       <td><a href="https://open.spotify.com/track/58oeJn3WUNbOBwaDFLgYL3" target="_blank">https://open.spotify.com/track/58oeJn3WUNbOBwaDFLgYL3</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Giovani eroi (feat. Not Good)</td>
#       <td>1aSRwLXZ5n7PlLWcle2CyO</td>
#       <td>2.55</td>
#       <td><a href="https://open.spotify.com/track/1aSRwLXZ5n7PlLWcle2CyO" target="_blank">https://open.spotify.com/track/1aSRwLXZ5n7PlLWcle2CyO</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Nel male e nel bene (feat. Massimo Pericolo)</td>
#       <td>0gpmaIaAS74HHiCoO462xj</td>
#       <td>3.18</td>
#       <td><a href="https://open.spotify.com/track/0gpmaIaAS74HHiCoO462xj" target="_blank">https://open.spotify.com/track/0gpmaIaAS74HHiCoO462xj</a></td>
#       <td>Keta Music, Vol. 3</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "17 - Dark Edition" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Crudo</td>
#       <td>1ygZfpABExUIUVtb15WgmJ</td>
#       <td>2.81</td>
#       <td><a href="https://open.spotify.com/track/1ygZfpABExUIUVtb15WgmJ" target="_blank">https://open.spotify.com/track/1ygZfpABExUIUVtb15WgmJ</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>No Cap (feat. Geolier)</td>
#       <td>3uqFFmxrCv4nzkKFSNbXHv</td>
#       <td>3.22</td>
#       <td><a href="https://open.spotify.com/track/3uqFFmxrCv4nzkKFSNbXHv" target="_blank">https://open.spotify.com/track/3uqFFmxrCv4nzkKFSNbXHv</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Per Tutta La Città (feat. Ernia)</td>
#       <td>2yPQPbigyqnHeKwWLTpnWu</td>
#       <td>2.77</td>
#       <td><a href="https://open.spotify.com/track/2yPQPbigyqnHeKwWLTpnWu" target="_blank">https://open.spotify.com/track/2yPQPbigyqnHeKwWLTpnWu</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Ok Così</td>
#       <td>0WqVAPT8FENj7AUyO2nAJ0</td>
#       <td>2.46</td>
#       <td><a href="https://open.spotify.com/track/0WqVAPT8FENj7AUyO2nAJ0" target="_blank">https://open.spotify.com/track/0WqVAPT8FENj7AUyO2nAJ0</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Più Lei Che Noi (feat. Rkomi)</td>
#       <td>6BWss9k0eYlgBmU2UUVZt4</td>
#       <td>3.06</td>
#       <td><a href="https://open.spotify.com/track/6BWss9k0eYlgBmU2UUVZt4" target="_blank">https://open.spotify.com/track/6BWss9k0eYlgBmU2UUVZt4</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>L'Ultima Volta RMX (feat. Speranza)</td>
#       <td>4GhsWHWoO0phlE5bUYLTlF</td>
#       <td>3.61</td>
#       <td><a href="https://open.spotify.com/track/4GhsWHWoO0phlE5bUYLTlF" target="_blank">https://open.spotify.com/track/4GhsWHWoO0phlE5bUYLTlF</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Il Seme Del Male RMX (feat. Not Good & Inamos)</td>
#       <td>5qqzUrGlnjqsJdvA8TQ7EJ</td>
#       <td>2.71</td>
#       <td><a href="https://open.spotify.com/track/5qqzUrGlnjqsJdvA8TQ7EJ" target="_blank">https://open.spotify.com/track/5qqzUrGlnjqsJdvA8TQ7EJ</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Broken Language</td>
#       <td>6c6n8mNJEVXtOWk8DGdzbA</td>
#       <td>1.82</td>
#       <td><a href="https://open.spotify.com/track/6c6n8mNJEVXtOWk8DGdzbA" target="_blank">https://open.spotify.com/track/6c6n8mNJEVXtOWk8DGdzbA</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Malandrino</td>
#       <td>2Pns0FO7cWmuHzulWvjJDy</td>
#       <td>3.02</td>
#       <td><a href="https://open.spotify.com/track/2Pns0FO7cWmuHzulWvjJDy" target="_blank">https://open.spotify.com/track/2Pns0FO7cWmuHzulWvjJDy</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>No Insta - feat. Lazza</td>
#       <td>5kgQU6stuVO7HiYeTBw6qe</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/5kgQU6stuVO7HiYeTBw6qe" target="_blank">https://open.spotify.com/track/5kgQU6stuVO7HiYeTBw6qe</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Renè & Francis</td>
#       <td>2Tsv8BeHSTvf6fQ00jYtv0</td>
#       <td>2.95</td>
#       <td><a href="https://open.spotify.com/track/2Tsv8BeHSTvf6fQ00jYtv0" target="_blank">https://open.spotify.com/track/2Tsv8BeHSTvf6fQ00jYtv0</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Amore tossico</td>
#       <td>4N3a8Az2DHZuZU8g7cNhK2</td>
#       <td>3.20</td>
#       <td><a href="https://open.spotify.com/track/4N3a8Az2DHZuZU8g7cNhK2" target="_blank">https://open.spotify.com/track/4N3a8Az2DHZuZU8g7cNhK2</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>666</td>
#       <td>12Jnt3v5OLoAekFjL6IIM7</td>
#       <td>2.36</td>
#       <td><a href="https://open.spotify.com/track/12Jnt3v5OLoAekFjL6IIM7" target="_blank">https://open.spotify.com/track/12Jnt3v5OLoAekFjL6IIM7</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Sparami - feat. Salmo, Fabri Fibra</td>
#       <td>43Rbz026pzedJcxHsFPkwX</td>
#       <td>3.13</td>
#       <td><a href="https://open.spotify.com/track/43Rbz026pzedJcxHsFPkwX" target="_blank">https://open.spotify.com/track/43Rbz026pzedJcxHsFPkwX</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Lontano da me</td>
#       <td>2aXvay8mea8AaDS0sWdoe8</td>
#       <td>3.75</td>
#       <td><a href="https://open.spotify.com/track/2aXvay8mea8AaDS0sWdoe8" target="_blank">https://open.spotify.com/track/2aXvay8mea8AaDS0sWdoe8</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Maleducato</td>
#       <td>6LPlkmzsTVzcrmp34tXIBu</td>
#       <td>2.88</td>
#       <td><a href="https://open.spotify.com/track/6LPlkmzsTVzcrmp34tXIBu" target="_blank">https://open.spotify.com/track/6LPlkmzsTVzcrmp34tXIBu</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>L'ultima volta - feat. Massimo Pericolo</td>
#       <td>05BK5sHkgs6RENgXP2bxnL</td>
#       <td>3.52</td>
#       <td><a href="https://open.spotify.com/track/05BK5sHkgs6RENgXP2bxnL" target="_blank">https://open.spotify.com/track/05BK5sHkgs6RENgXP2bxnL</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>La mia prigione</td>
#       <td>066Vxv7mJeERdDFm65nXky</td>
#       <td>2.68</td>
#       <td><a href="https://open.spotify.com/track/066Vxv7mJeERdDFm65nXky" target="_blank">https://open.spotify.com/track/066Vxv7mJeERdDFm65nXky</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Toro Loco</td>
#       <td>1lNx2mEzbuXrREINgEtUhy</td>
#       <td>2.74</td>
#       <td><a href="https://open.spotify.com/track/1lNx2mEzbuXrREINgEtUhy" target="_blank">https://open.spotify.com/track/1lNx2mEzbuXrREINgEtUhy</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Gli amici miei - feat. Lazza</td>
#       <td>3F94ty9y0VyYCXiyj5f027</td>
#       <td>4.48</td>
#       <td><a href="https://open.spotify.com/track/3F94ty9y0VyYCXiyj5f027" target="_blank">https://open.spotify.com/track/3F94ty9y0VyYCXiyj5f027</a></td>
#       <td>17 - Dark Edition</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "17" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Broken Language</td>
#       <td>6SUnPCMXpUvJ7ZiSFRg8rs</td>
#       <td>1.82</td>
#       <td><a href="https://open.spotify.com/track/6SUnPCMXpUvJ7ZiSFRg8rs" target="_blank">https://open.spotify.com/track/6SUnPCMXpUvJ7ZiSFRg8rs</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Malandrino</td>
#       <td>5CxxEOnXCU1BrFVg1cNtyH</td>
#       <td>3.02</td>
#       <td><a href="https://open.spotify.com/track/5CxxEOnXCU1BrFVg1cNtyH" target="_blank">https://open.spotify.com/track/5CxxEOnXCU1BrFVg1cNtyH</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>No Insta - feat. Lazza</td>
#       <td>3uHVhjDeFz9wF4Sf7wX6iU</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/3uHVhjDeFz9wF4Sf7wX6iU" target="_blank">https://open.spotify.com/track/3uHVhjDeFz9wF4Sf7wX6iU</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Renè & Francis</td>
#       <td>1xg3kuOWt3OXvI3TscVDaQ</td>
#       <td>2.95</td>
#       <td><a href="https://open.spotify.com/track/1xg3kuOWt3OXvI3TscVDaQ" target="_blank">https://open.spotify.com/track/1xg3kuOWt3OXvI3TscVDaQ</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Amore tossico</td>
#       <td>2ZiSzj3pQ0mZaNEMMuqQh5</td>
#       <td>3.20</td>
#       <td><a href="https://open.spotify.com/track/2ZiSzj3pQ0mZaNEMMuqQh5" target="_blank">https://open.spotify.com/track/2ZiSzj3pQ0mZaNEMMuqQh5</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>666</td>
#       <td>3jQU5EUwG8vac5LepBlbIu</td>
#       <td>2.36</td>
#       <td><a href="https://open.spotify.com/track/3jQU5EUwG8vac5LepBlbIu" target="_blank">https://open.spotify.com/track/3jQU5EUwG8vac5LepBlbIu</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Sparami - feat. Salmo, Fabri Fibra</td>
#       <td>2goEcSJEnmaHyKgmBJJzNm</td>
#       <td>3.13</td>
#       <td><a href="https://open.spotify.com/track/2goEcSJEnmaHyKgmBJJzNm" target="_blank">https://open.spotify.com/track/2goEcSJEnmaHyKgmBJJzNm</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Lontano da me</td>
#       <td>66cuNz5ezu7kKuH9APLruU</td>
#       <td>3.75</td>
#       <td><a href="https://open.spotify.com/track/66cuNz5ezu7kKuH9APLruU" target="_blank">https://open.spotify.com/track/66cuNz5ezu7kKuH9APLruU</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Maleducato</td>
#       <td>3riPXZtSlwdrhMGk76jBw3</td>
#       <td>2.88</td>
#       <td><a href="https://open.spotify.com/track/3riPXZtSlwdrhMGk76jBw3" target="_blank">https://open.spotify.com/track/3riPXZtSlwdrhMGk76jBw3</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>L'ultima volta - feat. Massimo Pericolo</td>
#       <td>3rOw9WmYFCRLHTRcbOjhUl</td>
#       <td>3.52</td>
#       <td><a href="https://open.spotify.com/track/3rOw9WmYFCRLHTRcbOjhUl" target="_blank">https://open.spotify.com/track/3rOw9WmYFCRLHTRcbOjhUl</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>La mia prigione</td>
#       <td>5Y54kl3xbHe6QI0igiznzE</td>
#       <td>2.68</td>
#       <td><a href="https://open.spotify.com/track/5Y54kl3xbHe6QI0igiznzE" target="_blank">https://open.spotify.com/track/5Y54kl3xbHe6QI0igiznzE</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Toro Loco</td>
#       <td>4lTFQjsjvuxTTq4L9qe82c</td>
#       <td>2.74</td>
#       <td><a href="https://open.spotify.com/track/4lTFQjsjvuxTTq4L9qe82c" target="_blank">https://open.spotify.com/track/4lTFQjsjvuxTTq4L9qe82c</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Gli amici miei - feat. Lazza</td>
#       <td>4BZCIqyBGmU1jeo4zPA8vb</td>
#       <td>4.48</td>
#       <td><a href="https://open.spotify.com/track/4BZCIqyBGmU1jeo4zPA8vb" target="_blank">https://open.spotify.com/track/4BZCIqyBGmU1jeo4zPA8vb</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Medaglia</td>
#       <td>7AnQncZKcaqSq7peG0pvaQ</td>
#       <td>3.30</td>
#       <td><a href="https://open.spotify.com/track/7AnQncZKcaqSq7peG0pvaQ" target="_blank">https://open.spotify.com/track/7AnQncZKcaqSq7peG0pvaQ</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Il Seme del Male</td>
#       <td>7qcj4WcYAy8RUzu8QPUWSg</td>
#       <td>2.59</td>
#       <td><a href="https://open.spotify.com/track/7qcj4WcYAy8RUzu8QPUWSg" target="_blank">https://open.spotify.com/track/7qcj4WcYAy8RUzu8QPUWSg</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Cowboy - feat. Tedua</td>
#       <td>3Pk5QS6oHK5qgCSmxaqwYn</td>
#       <td>3.01</td>
#       <td><a href="https://open.spotify.com/track/3Pk5QS6oHK5qgCSmxaqwYn" target="_blank">https://open.spotify.com/track/3Pk5QS6oHK5qgCSmxaqwYn</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Quello che non ho</td>
#       <td>3YJN7uSkunGJolNAb9JhiX</td>
#       <td>3.55</td>
#       <td><a href="https://open.spotify.com/track/3YJN7uSkunGJolNAb9JhiX" target="_blank">https://open.spotify.com/track/3YJN7uSkunGJolNAb9JhiX</a></td>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Supereroe Bat Edition" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Tijuana</td>
#       <td>2GSyQT0TRsOuaKyNt4msTi</td>
#       <td>3.03</td>
#       <td><a href="https://open.spotify.com/track/2GSyQT0TRsOuaKyNt4msTi" target="_blank">https://open.spotify.com/track/2GSyQT0TRsOuaKyNt4msTi</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>1PNDIvLQ2rFQuLC2YncOR5</td>
#       <td>2.77</td>
#       <td><a href="https://open.spotify.com/track/1PNDIvLQ2rFQuLC2YncOR5" target="_blank">https://open.spotify.com/track/1PNDIvLQ2rFQuLC2YncOR5</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Montecarlo</td>
#       <td>4TbB3Lj1R89e1hOF3Yx8sb</td>
#       <td>3.28</td>
#       <td><a href="https://open.spotify.com/track/4TbB3Lj1R89e1hOF3Yx8sb" target="_blank">https://open.spotify.com/track/4TbB3Lj1R89e1hOF3Yx8sb</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>La mia malattia</td>
#       <td>40zlOHTyzTrXYdISfMU7X4</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/40zlOHTyzTrXYdISfMU7X4" target="_blank">https://open.spotify.com/track/40zlOHTyzTrXYdISfMU7X4</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Open Water</td>
#       <td>3jvrh4fxGq2N5Vfup80GF6</td>
#       <td>3.09</td>
#       <td><a href="https://open.spotify.com/track/3jvrh4fxGq2N5Vfup80GF6" target="_blank">https://open.spotify.com/track/3jvrh4fxGq2N5Vfup80GF6</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Fuoco e benzina</td>
#       <td>6tFqZrn8juKP7mjHsHi6Kx</td>
#       <td>3.49</td>
#       <td><a href="https://open.spotify.com/track/6tFqZrn8juKP7mjHsHi6Kx" target="_blank">https://open.spotify.com/track/6tFqZrn8juKP7mjHsHi6Kx</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Cocaina</td>
#       <td>0IIAO3A7VGjt3H76Y5JuiQ</td>
#       <td>3.48</td>
#       <td><a href="https://open.spotify.com/track/0IIAO3A7VGjt3H76Y5JuiQ" target="_blank">https://open.spotify.com/track/0IIAO3A7VGjt3H76Y5JuiQ</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Donald Trump</td>
#       <td>53hFKKF9nj8x42N4zvCIaV</td>
#       <td>2.81</td>
#       <td><a href="https://open.spotify.com/track/53hFKKF9nj8x42N4zvCIaV" target="_blank">https://open.spotify.com/track/53hFKKF9nj8x42N4zvCIaV</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Rollercoaster</td>
#       <td>3ivsN7ywKXoIvbpr6dINsq</td>
#       <td>3.46</td>
#       <td><a href="https://open.spotify.com/track/3ivsN7ywKXoIvbpr6dINsq" target="_blank">https://open.spotify.com/track/3ivsN7ywKXoIvbpr6dINsq</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Senza cuore & senza nome</td>
#       <td>7CSzO105but5zsxPjPPofL</td>
#       <td>2.91</td>
#       <td><a href="https://open.spotify.com/track/7CSzO105but5zsxPjPPofL" target="_blank">https://open.spotify.com/track/7CSzO105but5zsxPjPPofL</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Claro</td>
#       <td>58zZbpjzHkdChIAMrJoq9i</td>
#       <td>3.73</td>
#       <td><a href="https://open.spotify.com/track/58zZbpjzHkdChIAMrJoq9i" target="_blank">https://open.spotify.com/track/58zZbpjzHkdChIAMrJoq9i</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Quella foto di noi due</td>
#       <td>1kWkHzfaazJZgaL16WkfS5</td>
#       <td>3.25</td>
#       <td><a href="https://open.spotify.com/track/1kWkHzfaazJZgaL16WkfS5" target="_blank">https://open.spotify.com/track/1kWkHzfaazJZgaL16WkfS5</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Adios</td>
#       <td>7LQSIPEXiCb1ynoOzujuvQ</td>
#       <td>3.21</td>
#       <td><a href="https://open.spotify.com/track/7LQSIPEXiCb1ynoOzujuvQ" target="_blank">https://open.spotify.com/track/7LQSIPEXiCb1ynoOzujuvQ</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Supereroe</td>
#       <td>0xghy9vnE4K1q34WfhfmXP</td>
#       <td>3.77</td>
#       <td><a href="https://open.spotify.com/track/0xghy9vnE4K1q34WfhfmXP" target="_blank">https://open.spotify.com/track/0xghy9vnE4K1q34WfhfmXP</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Dope 2</td>
#       <td>05WoO4LmgR9PXGL9EpFb1a</td>
#       <td>2.86</td>
#       <td><a href="https://open.spotify.com/track/05WoO4LmgR9PXGL9EpFb1a" target="_blank">https://open.spotify.com/track/05WoO4LmgR9PXGL9EpFb1a</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Come fossimo cowboy</td>
#       <td>1cgtLiezsB2FdcfL79MJ1k</td>
#       <td>3.25</td>
#       <td><a href="https://open.spotify.com/track/1cgtLiezsB2FdcfL79MJ1k" target="_blank">https://open.spotify.com/track/1cgtLiezsB2FdcfL79MJ1k</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Mille strade</td>
#       <td>1LR4QF635P1eosTFIBduij</td>
#       <td>3.53</td>
#       <td><a href="https://open.spotify.com/track/1LR4QF635P1eosTFIBduij" target="_blank">https://open.spotify.com/track/1LR4QF635P1eosTFIBduij</a></td>
#       <td>Supereroe Bat Edition</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Supereroe" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Open Water</td>
#       <td>3kGxtPDusqTr6r2N5k25t1</td>
#       <td>3.09</td>
#       <td><a href="https://open.spotify.com/track/3kGxtPDusqTr6r2N5k25t1" target="_blank">https://open.spotify.com/track/3kGxtPDusqTr6r2N5k25t1</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Fuoco e benzina</td>
#       <td>4Fs1sEg9Mwn6vykFD89xvc</td>
#       <td>3.49</td>
#       <td><a href="https://open.spotify.com/track/4Fs1sEg9Mwn6vykFD89xvc" target="_blank">https://open.spotify.com/track/4Fs1sEg9Mwn6vykFD89xvc</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cocaina</td>
#       <td>3LuuuNvULPU1GOfSg0HG62</td>
#       <td>3.48</td>
#       <td><a href="https://open.spotify.com/track/3LuuuNvULPU1GOfSg0HG62" target="_blank">https://open.spotify.com/track/3LuuuNvULPU1GOfSg0HG62</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Donald Trump</td>
#       <td>2lDI8OOVE5UgLiNP6AVCzF</td>
#       <td>2.81</td>
#       <td><a href="https://open.spotify.com/track/2lDI8OOVE5UgLiNP6AVCzF" target="_blank">https://open.spotify.com/track/2lDI8OOVE5UgLiNP6AVCzF</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Rollercoaster</td>
#       <td>4WJj8NsyCm3YAADCOe0hrf</td>
#       <td>3.46</td>
#       <td><a href="https://open.spotify.com/track/4WJj8NsyCm3YAADCOe0hrf" target="_blank">https://open.spotify.com/track/4WJj8NsyCm3YAADCOe0hrf</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Senza cuore & senza nome</td>
#       <td>5Q8rYh7lFHzzdSzJdy4oTF</td>
#       <td>2.91</td>
#       <td><a href="https://open.spotify.com/track/5Q8rYh7lFHzzdSzJdy4oTF" target="_blank">https://open.spotify.com/track/5Q8rYh7lFHzzdSzJdy4oTF</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Claro</td>
#       <td>6W2f9IsLo8nLFw301YjrrY</td>
#       <td>3.73</td>
#       <td><a href="https://open.spotify.com/track/6W2f9IsLo8nLFw301YjrrY" target="_blank">https://open.spotify.com/track/6W2f9IsLo8nLFw301YjrrY</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Quella foto di noi due</td>
#       <td>10hc6GvyWhe2E48PAfQrdD</td>
#       <td>3.25</td>
#       <td><a href="https://open.spotify.com/track/10hc6GvyWhe2E48PAfQrdD" target="_blank">https://open.spotify.com/track/10hc6GvyWhe2E48PAfQrdD</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Adios</td>
#       <td>0s4jZrI4JfgFqf637JqBZA</td>
#       <td>3.21</td>
#       <td><a href="https://open.spotify.com/track/0s4jZrI4JfgFqf637JqBZA" target="_blank">https://open.spotify.com/track/0s4jZrI4JfgFqf637JqBZA</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Supereroe</td>
#       <td>7uRwfVTXZRSOEpruUyXWMb</td>
#       <td>3.77</td>
#       <td><a href="https://open.spotify.com/track/7uRwfVTXZRSOEpruUyXWMb" target="_blank">https://open.spotify.com/track/7uRwfVTXZRSOEpruUyXWMb</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Dope 2</td>
#       <td>4AsvicHWhsUfzPWPiC31cF</td>
#       <td>2.86</td>
#       <td><a href="https://open.spotify.com/track/4AsvicHWhsUfzPWPiC31cF" target="_blank">https://open.spotify.com/track/4AsvicHWhsUfzPWPiC31cF</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Come fossimo cowboy</td>
#       <td>54o1G7sQQfdWjLAI4KJ2AW</td>
#       <td>3.25</td>
#       <td><a href="https://open.spotify.com/track/54o1G7sQQfdWjLAI4KJ2AW" target="_blank">https://open.spotify.com/track/54o1G7sQQfdWjLAI4KJ2AW</a></td>
#       <td>Supereroe</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Mille strade</td>
#       <td>15BbP2LwE19MqI2uacrJFx</td>
#       <td>3.53</td>
#       <td><a href="https://open.spotify.com/track/15BbP2LwE19MqI2uacrJFx" target="_blank">https://open.spotify.com/track/15BbP2LwE19MqI2uacrJFx</a></td>
#       <td>Supereroe</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Terza Stagione" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Dal basso</td>
#       <td>43p3mf4ZB1gwa6mKUSUkEP</td>
#       <td>3.40</td>
#       <td><a href="https://open.spotify.com/track/43p3mf4ZB1gwa6mKUSUkEP" target="_blank">https://open.spotify.com/track/43p3mf4ZB1gwa6mKUSUkEP</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Non era vero</td>
#       <td>4Xd6MuMMX41dQbavX4Rq1q</td>
#       <td>3.81</td>
#       <td><a href="https://open.spotify.com/track/4Xd6MuMMX41dQbavX4Rq1q" target="_blank">https://open.spotify.com/track/4Xd6MuMMX41dQbavX4Rq1q</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Prima che sia lunedì</td>
#       <td>6cNtriRBJjOSwEGcd5LUsS</td>
#       <td>3.13</td>
#       <td><a href="https://open.spotify.com/track/6cNtriRBJjOSwEGcd5LUsS" target="_blank">https://open.spotify.com/track/6cNtriRBJjOSwEGcd5LUsS</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Italian Dream</td>
#       <td>1ku8M71ukCuw0vmTpsaJqC</td>
#       <td>2.93</td>
#       <td><a href="https://open.spotify.com/track/1ku8M71ukCuw0vmTpsaJqC" target="_blank">https://open.spotify.com/track/1ku8M71ukCuw0vmTpsaJqC</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Quello di prima</td>
#       <td>40EFyfU7nJxnTzLY8jNfQR</td>
#       <td>3.85</td>
#       <td><a href="https://open.spotify.com/track/40EFyfU7nJxnTzLY8jNfQR" target="_blank">https://open.spotify.com/track/40EFyfU7nJxnTzLY8jNfQR</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Parigi (feat. Neffa)</td>
#       <td>5ierkPgrIUtxNuHe5qE1AK</td>
#       <td>3.17</td>
#       <td><a href="https://open.spotify.com/track/5ierkPgrIUtxNuHe5qE1AK" target="_blank">https://open.spotify.com/track/5ierkPgrIUtxNuHe5qE1AK</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Uno come me</td>
#       <td>5qscY4wKKTtzoLhxEBvGoi</td>
#       <td>3.42</td>
#       <td><a href="https://open.spotify.com/track/5qscY4wKKTtzoLhxEBvGoi" target="_blank">https://open.spotify.com/track/5qscY4wKKTtzoLhxEBvGoi</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Non è facile (feat. Jake La Furia)</td>
#       <td>4xpfcZQOk16WVGRLGhFTEc</td>
#       <td>3.38</td>
#       <td><a href="https://open.spotify.com/track/4xpfcZQOk16WVGRLGhFTEc" target="_blank">https://open.spotify.com/track/4xpfcZQOk16WVGRLGhFTEc</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Jack</td>
#       <td>3CBkGr9XwKJ5nsI4VvNcup</td>
#       <td>3.77</td>
#       <td><a href="https://open.spotify.com/track/3CBkGr9XwKJ5nsI4VvNcup" target="_blank">https://open.spotify.com/track/3CBkGr9XwKJ5nsI4VvNcup</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>All'alba delle 6:00 (feat. Coez)</td>
#       <td>4IAIe2ehYOp4TaCbSARv7t</td>
#       <td>3.65</td>
#       <td><a href="https://open.spotify.com/track/4IAIe2ehYOp4TaCbSARv7t" target="_blank">https://open.spotify.com/track/4IAIe2ehYOp4TaCbSARv7t</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Sopravvissuto (feat. Fabri Fibra)</td>
#       <td>3R2odoWzAQDgA9nwfXigzV</td>
#       <td>3.20</td>
#       <td><a href="https://open.spotify.com/track/3R2odoWzAQDgA9nwfXigzV" target="_blank">https://open.spotify.com/track/3R2odoWzAQDgA9nwfXigzV</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Su di lei</td>
#       <td>0lCDOuPx9wwTtF7dLovqNk</td>
#       <td>3.88</td>
#       <td><a href="https://open.spotify.com/track/0lCDOuPx9wwTtF7dLovqNk" target="_blank">https://open.spotify.com/track/0lCDOuPx9wwTtF7dLovqNk</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>CULT</td>
#       <td>2nOoviDQk284lepBFFQv7r</td>
#       <td>3.78</td>
#       <td><a href="https://open.spotify.com/track/2nOoviDQk284lepBFFQv7r" target="_blank">https://open.spotify.com/track/2nOoviDQk284lepBFFQv7r</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>3 messaggi in segreteria</td>
#       <td>75l1pp3XhKoc1UNMVLpJUG</td>
#       <td>3.45</td>
#       <td><a href="https://open.spotify.com/track/75l1pp3XhKoc1UNMVLpJUG" target="_blank">https://open.spotify.com/track/75l1pp3XhKoc1UNMVLpJUG</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Buonanotte (feat. Maruego) [Scratch by Telaviv]</td>
#       <td>68pDfyeKOAV9ZchmwP2csr</td>
#       <td>3.81</td>
#       <td><a href="https://open.spotify.com/track/68pDfyeKOAV9ZchmwP2csr" target="_blank">https://open.spotify.com/track/68pDfyeKOAV9ZchmwP2csr</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Vecchia maniera (feat. Giso e Jamil)</td>
#       <td>3Lq5zePX18556GZYC7qhNe</td>
#       <td>4.59</td>
#       <td><a href="https://open.spotify.com/track/3Lq5zePX18556GZYC7qhNe" target="_blank">https://open.spotify.com/track/3Lq5zePX18556GZYC7qhNe</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Vestiti sporchi (Scratch by 2P)</td>
#       <td>0RMQ4ubWp2GlGE3Pi8ZPbs</td>
#       <td>3.42</td>
#       <td><a href="https://open.spotify.com/track/0RMQ4ubWp2GlGE3Pi8ZPbs" target="_blank">https://open.spotify.com/track/0RMQ4ubWp2GlGE3Pi8ZPbs</a></td>
#       <td>Terza Stagione</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Keta Music - Volume 2" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Lo sanno i veri (intro) - prod. by Davide Ice (feat. Dj Telaviv)</td>
#       <td>3pemEexg3TxbDm6wCByvFC</td>
#       <td>2.19</td>
#       <td><a href="https://open.spotify.com/track/3pemEexg3TxbDm6wCByvFC" target="_blank">https://open.spotify.com/track/3pemEexg3TxbDm6wCByvFC</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C'era una volta - prod. by Big Joe</td>
#       <td>1P5uBYw3NpYFuoPQeTswst</td>
#       <td>2.46</td>
#       <td><a href="https://open.spotify.com/track/1P5uBYw3NpYFuoPQeTswst" target="_blank">https://open.spotify.com/track/1P5uBYw3NpYFuoPQeTswst</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Superman - prod. by Zef (feat. Guè)</td>
#       <td>2wFhYRBc8JzVkRv8c01zU4</td>
#       <td>3.16</td>
#       <td><a href="https://open.spotify.com/track/2wFhYRBc8JzVkRv8c01zU4" target="_blank">https://open.spotify.com/track/2wFhYRBc8JzVkRv8c01zU4</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>13 anni - prod. by Don Joe (feat. Bassi Maestro, Giso e Clark P.)</td>
#       <td>3JcHbkGwXDoZtoT743gGtn</td>
#       <td>3.21</td>
#       <td><a href="https://open.spotify.com/track/3JcHbkGwXDoZtoT743gGtn" target="_blank">https://open.spotify.com/track/3JcHbkGwXDoZtoT743gGtn</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>B.Rex Bestie - prod. by Sick Luke (feat. Lazza)</td>
#       <td>1uOBgCSyFH0DFa4r5tDZhn</td>
#       <td>3.60</td>
#       <td><a href="https://open.spotify.com/track/1uOBgCSyFH0DFa4r5tDZhn" target="_blank">https://open.spotify.com/track/1uOBgCSyFH0DFa4r5tDZhn</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Racai status - prod. by Mondo Marcio (feat. Vacca e Jamil)</td>
#       <td>1GZb1rdyPeH9ma2aYxHZYh</td>
#       <td>3.25</td>
#       <td><a href="https://open.spotify.com/track/1GZb1rdyPeH9ma2aYxHZYh" target="_blank">https://open.spotify.com/track/1GZb1rdyPeH9ma2aYxHZYh</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>10 comandamenti - prod. by Pk (feat. Gemitaiz & Madman)</td>
#       <td>3dh5jD1jlmUyEDzLMYhvYY</td>
#       <td>5.05</td>
#       <td><a href="https://open.spotify.com/track/3dh5jD1jlmUyEDzLMYhvYY" target="_blank">https://open.spotify.com/track/3dh5jD1jlmUyEDzLMYhvYY</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Champions - prod. by 2nd Roof Music (feat. Clementino)</td>
#       <td>4zNKXU1HM8YtxoslBdAl4I</td>
#       <td>3.34</td>
#       <td><a href="https://open.spotify.com/track/4zNKXU1HM8YtxoslBdAl4I" target="_blank">https://open.spotify.com/track/4zNKXU1HM8YtxoslBdAl4I</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Di tutti i colori - prod. by Pk (feat. Jake La Furia)</td>
#       <td>468aNavUHoxQQZXatMXEqS</td>
#       <td>3.43</td>
#       <td><a href="https://open.spotify.com/track/468aNavUHoxQQZXatMXEqS" target="_blank">https://open.spotify.com/track/468aNavUHoxQQZXatMXEqS</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Martin Luther King - prod. by Small White (feat. Luchè)</td>
#       <td>4UffiDQcLsky7mQan14i5a</td>
#       <td>4.22</td>
#       <td><a href="https://open.spotify.com/track/4UffiDQcLsky7mQan14i5a" target="_blank">https://open.spotify.com/track/4UffiDQcLsky7mQan14i5a</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Bella idea - prod. by Zef (feat. Lazza)</td>
#       <td>6c1db1UvoUKcl2NPPwbKV2</td>
#       <td>3.47</td>
#       <td><a href="https://open.spotify.com/track/6c1db1UvoUKcl2NPPwbKV2" target="_blank">https://open.spotify.com/track/6c1db1UvoUKcl2NPPwbKV2</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Casinò - prod. by 2nd Roof Music (feat. Maruego)</td>
#       <td>4VDD3F54TlvXwNIEsGaCGT</td>
#       <td>3.65</td>
#       <td><a href="https://open.spotify.com/track/4VDD3F54TlvXwNIEsGaCGT" target="_blank">https://open.spotify.com/track/4VDD3F54TlvXwNIEsGaCGT</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Colpo di fulmine (outro) - prod. by Fritz Da Cat</td>
#       <td>1lVSYZ9zS18ZTTSSb6NHKn</td>
#       <td>2.33</td>
#       <td><a href="https://open.spotify.com/track/1lVSYZ9zS18ZTTSSb6NHKn" target="_blank">https://open.spotify.com/track/1lVSYZ9zS18ZTTSSb6NHKn</a></td>
#       <td>Keta Music - Volume 2</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Mercurio - 5 Stars Edition" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
# ...
#       <td>L'erba cattiva (Gold Edition)</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Tutto quello che ho (feat. Fabio De Martino)</td>
#       <td>6tTivCNJVhxoJTh0sMfLRq</td>
#       <td>4.64</td>
#       <td><a href="https://open.spotify.com/track/6tTivCNJVhxoJTh0sMfLRq" target="_blank">https://open.spotify.com/track/6tTivCNJVhxoJTh0sMfLRq</a></td>
#       <td>L'erba cattiva (Gold Edition)</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>È meglio così</td>
#       <td>5BikUwuGOwKJnRf04wELl1</td>
#       <td>3.55</td>
#       <td><a href="https://open.spotify.com/track/5BikUwuGOwKJnRf04wELl1" target="_blank">https://open.spotify.com/track/5BikUwuGOwKJnRf04wELl1</a></td>
#       <td>L'erba cattiva (Gold Edition)</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Chissà se</td>
#       <td>08KvlRkorqaPij4wKRGtw6</td>
#       <td>3.54</td>
#       <td><a href="https://open.spotify.com/track/08KvlRkorqaPij4wKRGtw6" target="_blank">https://open.spotify.com/track/08KvlRkorqaPij4wKRGtw6</a></td>
#       <td>L'erba cattiva (Gold Edition)</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Il king</td>
#       <td>7EMF2NHd2L4JFVqEbykzkz</td>
#       <td>2.94</td>
#       <td><a href="https://open.spotify.com/track/7EMF2NHd2L4JFVqEbykzkz" target="_blank">https://open.spotify.com/track/7EMF2NHd2L4JFVqEbykzkz</a></td>
#       <td>L'erba cattiva (Gold Edition)</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Più rispetto (feat. Bassi Maestro)</td>
#       <td>4tDoPTaDmaBtMQxZs7Lg1v</td>
#       <td>3.42</td>
#       <td><a href="https://open.spotify.com/track/4tDoPTaDmaBtMQxZs7Lg1v" target="_blank">https://open.spotify.com/track/4tDoPTaDmaBtMQxZs7Lg1v</a></td>
#       <td>L'erba cattiva (Gold Edition)</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "L'erba cattiva" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sulla luna (intro)</td>
#       <td>1buww5F981MQVXAGxmstqi</td>
#       <td>2.13</td>
#       <td><a href="https://open.spotify.com/track/1buww5F981MQVXAGxmstqi" target="_blank">https://open.spotify.com/track/1buww5F981MQVXAGxmstqi</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Cashwoman</td>
#       <td>1FldPvjgo0awW4iqE7LeD6</td>
#       <td>2.89</td>
#       <td><a href="https://open.spotify.com/track/1FldPvjgo0awW4iqE7LeD6" target="_blank">https://open.spotify.com/track/1FldPvjgo0awW4iqE7LeD6</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Parole di ghiaccio</td>
#       <td>1mItEeAlTepKfWUOpu8h6b</td>
#       <td>3.86</td>
#       <td><a href="https://open.spotify.com/track/1mItEeAlTepKfWUOpu8h6b" target="_blank">https://open.spotify.com/track/1mItEeAlTepKfWUOpu8h6b</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Dietro front (feat. Fabri Fibra)</td>
#       <td>0fK885Y1i3Gcji2aSjXgxi</td>
#       <td>3.16</td>
#       <td><a href="https://open.spotify.com/track/0fK885Y1i3Gcji2aSjXgxi" target="_blank">https://open.spotify.com/track/0fK885Y1i3Gcji2aSjXgxi</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Come un pitbull</td>
#       <td>4rcYjC1FrBYLaW6WjyqOvs</td>
#       <td>3.68</td>
#       <td><a href="https://open.spotify.com/track/4rcYjC1FrBYLaW6WjyqOvs" target="_blank">https://open.spotify.com/track/4rcYjC1FrBYLaW6WjyqOvs</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Ognuno per sè (feat. Gue Pequeno)</td>
#       <td>6fucaL8AhR6bDZR8azPGVH</td>
#       <td>3.24</td>
#       <td><a href="https://open.spotify.com/track/6fucaL8AhR6bDZR8azPGVH" target="_blank">https://open.spotify.com/track/6fucaL8AhR6bDZR8azPGVH</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>L'erba cattiva</td>
#       <td>60R99qML47eSlhkW9MiHpC</td>
#       <td>3.92</td>
#       <td><a href="https://open.spotify.com/track/60R99qML47eSlhkW9MiHpC" target="_blank">https://open.spotify.com/track/60R99qML47eSlhkW9MiHpC</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Cocktailz (feat. G. Soave & Duellz)</td>
#       <td>1nfffKwF0xRCVxapyd9bNF</td>
#       <td>3.56</td>
#       <td><a href="https://open.spotify.com/track/1nfffKwF0xRCVxapyd9bNF" target="_blank">https://open.spotify.com/track/1nfffKwF0xRCVxapyd9bNF</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Nice pic</td>
#       <td>40couONRbDeQUTUjRZ1VGT</td>
#       <td>3.16</td>
#       <td><a href="https://open.spotify.com/track/40couONRbDeQUTUjRZ1VGT" target="_blank">https://open.spotify.com/track/40couONRbDeQUTUjRZ1VGT</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Nei guai (feat. Tormento)</td>
#       <td>7m7gqcqo16kGPItmJLt2Ge</td>
#       <td>3.24</td>
#       <td><a href="https://open.spotify.com/track/7m7gqcqo16kGPItmJLt2Ge" target="_blank">https://open.spotify.com/track/7m7gqcqo16kGPItmJLt2Ge</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Giusto o sbagliato</td>
#       <td>78hSVFuo1Ua2XHwrsq3AN3</td>
#       <td>3.26</td>
#       <td><a href="https://open.spotify.com/track/78hSVFuo1Ua2XHwrsq3AN3" target="_blank">https://open.spotify.com/track/78hSVFuo1Ua2XHwrsq3AN3</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Il mondo dei grandi (feat. Marracash)</td>
#       <td>7Kp4wxNf16wcKXTx6TnS0I</td>
#       <td>3.85</td>
#       <td><a href="https://open.spotify.com/track/7Kp4wxNf16wcKXTx6TnS0I" target="_blank">https://open.spotify.com/track/7Kp4wxNf16wcKXTx6TnS0I</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Tutto quello che ho (feat. Fabio De Martino)</td>
#       <td>5311P7319Q8eYkvREowMSb</td>
#       <td>4.64</td>
#       <td><a href="https://open.spotify.com/track/5311P7319Q8eYkvREowMSb" target="_blank">https://open.spotify.com/track/5311P7319Q8eYkvREowMSb</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Il peggiore</td>
#       <td>0RYKRfXaeKN8ZaB0XCpPvl</td>
#       <td>3.49</td>
#       <td><a href="https://open.spotify.com/track/0RYKRfXaeKN8ZaB0XCpPvl" target="_blank">https://open.spotify.com/track/0RYKRfXaeKN8ZaB0XCpPvl</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Di.Enne.A.</td>
#       <td>4221BpjBHA2JbTe5kpzaBD</td>
#       <td>4.30</td>
#       <td><a href="https://open.spotify.com/track/4221BpjBHA2JbTe5kpzaBD" target="_blank">https://open.spotify.com/track/4221BpjBHA2JbTe5kpzaBD</a></td>
#       <td>L'erba cattiva</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Il peggiore" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Il peggiore</td>
#       <td>7eU8uE8gE6wmfkSndkiwtd</td>
#       <td>3.49</td>
#       <td><a href="https://open.spotify.com/track/7eU8uE8gE6wmfkSndkiwtd" target="_blank">https://open.spotify.com/track/7eU8uE8gE6wmfkSndkiwtd</a></td>
#       <td>Il peggiore</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Tutti in catene</td>
#       <td>1EJQwsBex2jgROU2MeRR1r</td>
#       <td>3.27</td>
#       <td><a href="https://open.spotify.com/track/1EJQwsBex2jgROU2MeRR1r" target="_blank">https://open.spotify.com/track/1EJQwsBex2jgROU2MeRR1r</a></td>
#       <td>Il peggiore</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Io sono la moda</td>
#       <td>31d6MpKiZxzI5qOyQhonip</td>
#       <td>3.13</td>
#       <td><a href="https://open.spotify.com/track/31d6MpKiZxzI5qOyQhonip" target="_blank">https://open.spotify.com/track/31d6MpKiZxzI5qOyQhonip</a></td>
#       <td>Il peggiore</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>La bara più grande del mondo</td>
#       <td>5oIqNUjLNhw43IT2kxaPrL</td>
#       <td>3.71</td>
#       <td><a href="https://open.spotify.com/track/5oIqNUjLNhw43IT2kxaPrL" target="_blank">https://open.spotify.com/track/5oIqNUjLNhw43IT2kxaPrL</a></td>
#       <td>Il peggiore</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Stupefacente</td>
#       <td>3axwgN6Ed3vk8WqieZxtlf</td>
#       <td>3.62</td>
#       <td><a href="https://open.spotify.com/track/3axwgN6Ed3vk8WqieZxtlf" target="_blank">https://open.spotify.com/track/3axwgN6Ed3vk8WqieZxtlf</a></td>
#       <td>Il peggiore</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Qualcosa non va</td>
#       <td>28tnuf0OvuU4QuvEBIhlOa</td>
#       <td>2.76</td>
#       <td><a href="https://open.spotify.com/track/28tnuf0OvuU4QuvEBIhlOa" target="_blank">https://open.spotify.com/track/28tnuf0OvuU4QuvEBIhlOa</a></td>
#       <td>Il peggiore</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Sexy line</td>
#       <td>5fJeyRy0kRhWlkGaenxSkz</td>
#       <td>3.11</td>
#       <td><a href="https://open.spotify.com/track/5fJeyRy0kRhWlkGaenxSkz" target="_blank">https://open.spotify.com/track/5fJeyRy0kRhWlkGaenxSkz</a></td>
#       <td>Il peggiore</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================
#
# Le tracce dell'album "Champagne e spine" sono:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Click clack</td>
#       <td>5LQUa7pyDW13k6N4ir4Now</td>
#       <td>2.78</td>
#       <td><a href="https://open.spotify.com/track/5LQUa7pyDW13k6N4ir4Now" target="_blank">https://open.spotify.com/track/5LQUa7pyDW13k6N4ir4Now</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K.I.L.L.A.</td>
#       <td>3j2667Rcualn0KHlu7dHA1</td>
#       <td>3.37</td>
#       <td><a href="https://open.spotify.com/track/3j2667Rcualn0KHlu7dHA1" target="_blank">https://open.spotify.com/track/3j2667Rcualn0KHlu7dHA1</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ho visto</td>
#       <td>71NjwQutSebp8WDg4VLlgo</td>
#       <td>2.75</td>
#       <td><a href="https://open.spotify.com/track/71NjwQutSebp8WDg4VLlgo" target="_blank">https://open.spotify.com/track/71NjwQutSebp8WDg4VLlgo</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Romanzo criminale</td>
#       <td>0W3XeudDLeZxyssUX4oafA</td>
#       <td>3.78</td>
#       <td><a href="https://open.spotify.com/track/0W3XeudDLeZxyssUX4oafA" target="_blank">https://open.spotify.com/track/0W3XeudDLeZxyssUX4oafA</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Capo status</td>
#       <td>3QWHi6QU3dW4ov6FCx4tXa</td>
#       <td>2.80</td>
#       <td><a href="https://open.spotify.com/track/3QWHi6QU3dW4ov6FCx4tXa" target="_blank">https://open.spotify.com/track/3QWHi6QU3dW4ov6FCx4tXa</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Neve e fango</td>
#       <td>4e1u2SwPhvpYrpLqZLc5U9</td>
#       <td>2.97</td>
#       <td><a href="https://open.spotify.com/track/4e1u2SwPhvpYrpLqZLc5U9" target="_blank">https://open.spotify.com/track/4e1u2SwPhvpYrpLqZLc5U9</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>I'm the shit</td>
#       <td>70trzaC4ZvmTHlTSmBpfFt</td>
#       <td>2.54</td>
#       <td><a href="https://open.spotify.com/track/70trzaC4ZvmTHlTSmBpfFt" target="_blank">https://open.spotify.com/track/70trzaC4ZvmTHlTSmBpfFt</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>I 3 tempi</td>
#       <td>6PgFgApQ3J3i30pujwOwYy</td>
#       <td>3.75</td>
#       <td><a href="https://open.spotify.com/track/6PgFgApQ3J3i30pujwOwYy" target="_blank">https://open.spotify.com/track/6PgFgApQ3J3i30pujwOwYy</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Bla bla</td>
#       <td>34dr80dLl4si6Jkbwam5JR</td>
#       <td>3.11</td>
#       <td><a href="https://open.spotify.com/track/34dr80dLl4si6Jkbwam5JR" target="_blank">https://open.spotify.com/track/34dr80dLl4si6Jkbwam5JR</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Ombre</td>
#       <td>5CMTjpGOBKFyC96kkxXss3</td>
#       <td>3.07</td>
#       <td><a href="https://open.spotify.com/track/5CMTjpGOBKFyC96kkxXss3" target="_blank">https://open.spotify.com/track/5CMTjpGOBKFyC96kkxXss3</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Grigio</td>
#       <td>5x9Nxv8Oo8J0YPd4TB6BO0</td>
#       <td>4.50</td>
#       <td><a href="https://open.spotify.com/track/5x9Nxv8Oo8J0YPd4TB6BO0" target="_blank">https://open.spotify.com/track/5x9Nxv8Oo8J0YPd4TB6BO0</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Apatia</td>
#       <td>2ZFddsD888mmrhd0hco9S2</td>
#       <td>3.13</td>
#       <td><a href="https://open.spotify.com/track/2ZFddsD888mmrhd0hco9S2" target="_blank">https://open.spotify.com/track/2ZFddsD888mmrhd0hco9S2</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Milano male</td>
#       <td>6mKFZZNI5st7xTjV5ZnInt</td>
#       <td>2.36</td>
#       <td><a href="https://open.spotify.com/track/6mKFZZNI5st7xTjV5ZnInt" target="_blank">https://open.spotify.com/track/6mKFZZNI5st7xTjV5ZnInt</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Champagne e spine</td>
#       <td>5sHZPR5A8El4QwWF1F12FC</td>
#       <td>3.37</td>
#       <td><a href="https://open.spotify.com/track/5sHZPR5A8El4QwWF1F12FC" target="_blank">https://open.spotify.com/track/5sHZPR5A8El4QwWF1F12FC</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Conseguenze</td>
#       <td>0ZXaEbqwmgRsnmDiFAfNB5</td>
#       <td>2.97</td>
#       <td><a href="https://open.spotify.com/track/0ZXaEbqwmgRsnmDiFAfNB5" target="_blank">https://open.spotify.com/track/0ZXaEbqwmgRsnmDiFAfNB5</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Consapevolezza</td>
#       <td>6InoIABYwvO1DDy71KnZbS</td>
#       <td>2.82</td>
#       <td><a href="https://open.spotify.com/track/6InoIABYwvO1DDy71KnZbS" target="_blank">https://open.spotify.com/track/6InoIABYwvO1DDy71KnZbS</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Ciò che perdi</td>
#       <td>4spZRZr2KAgRrShsQ6baSC</td>
#       <td>2.10</td>
#       <td><a href="https://open.spotify.com/track/4spZRZr2KAgRrShsQ6baSC" target="_blank">https://open.spotify.com/track/4spZRZr2KAgRrShsQ6baSC</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Pum pum pum (Remix)</td>
#       <td>1KWRYWqDw6SBbjC77z2pXB</td>
#       <td>2.74</td>
#       <td><a href="https://open.spotify.com/track/1KWRYWqDw6SBbjC77z2pXB" target="_blank">https://open.spotify.com/track/1KWRYWqDw6SBbjC77z2pXB</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>B. Rex cricca</td>
#       <td>2UP4ArKNxK85xeIDXLPeX2</td>
#       <td>3.23</td>
#       <td><a href="https://open.spotify.com/track/2UP4ArKNxK85xeIDXLPeX2" target="_blank">https://open.spotify.com/track/2UP4ArKNxK85xeIDXLPeX2</a></td>
#       <td>Champagne e spine</td>
#     </tr>
#   </tbody>
# </table>
# ==========================================================================================================================================

# %% [markdown]
# - Si può anche visualizzare il dataframe globale e salvare in un apposito file csv:

# %%
print("\nDataFrame complessivo delle tracce:")
display(HTML(discography_data_frame.to_html(escape=False)))
discography_data_frame.to_csv('discography_data.csv', index=False)
# Out:
# DataFrame complessivo delle tracce:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PACINO - the godfather</td>
#       <td>0DJJkaSRugtaqVjWOItGn0</td>
#       <td>2.04</td>
#       <td><a href="https://open.spotify.com/track/0DJJkaSRugtaqVjWOItGn0" target="_blank">https://open.spotify.com/track/0DJJkaSRugtaqVjWOItGn0</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ON FIRE - paid in full</td>
#       <td>2pGbOFiWVwZaTq3iKi5sGb</td>
#       <td>2.93</td>
#       <td><a href="https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb" target="_blank">https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>COL CUORE IN GOLA - lords of dogtown</td>
#       <td>2ypcWaliFPJ9c3JeWMqi1w</td>
#       <td>3.14</td>
#       <td><a href="https://open.spotify.com/track/2ypcWaliFPJ9c3JeWMqi1w" target="_blank">https://open.spotify.com/track/2ypcWaliFPJ9c3JeWMqi1w</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>VISCERALE - closer</td>
#       <td>7bgJm5Z7EpvXRMdysiUjCj</td>
#       <td>3.07</td>
#       <td><a href="https://open.spotify.com/track/7bgJm5Z7EpvXRMdysiUjCj" target="_blank">https://open.spotify.com/track/7bgJm5Z7EpvXRMdysiUjCj</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>MASERATI - the wolf of wall street</td>
#       <td>3vZ3ZCdyr7jxBDKzgFtKBN</td>
#       <td>2.27</td>
#       <td><a href="https://open.spotify.com/track/3vZ3ZCdyr7jxBDKzgFtKBN" target="_blank">https://open.spotify.com/track/3vZ3ZCdyr7jxBDKzgFtKBN</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>LONTANO - carlito's way</td>
#       <td>2t1dculU2L9HxEIzB00Xpk</td>
#       <td>2.78</td>
#       <td><a href="https://open.spotify.com/track/2t1dculU2L9HxEIzB00Xpk" target="_blank">https://open.spotify.com/track/2t1dculU2L9HxEIzB00Xpk</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ALBICOCCA - lolita</td>
#       <td>1Bkq1PP6QZrZcpAyEnIKDy</td>
#       <td>2.71</td>
#       <td><a href="https://open.spotify.com/track/1Bkq1PP6QZrZcpAyEnIKDy" target="_blank">https://open.spotify.com/track/1Bkq1PP6QZrZcpAyEnIKDy</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BIG BANG - upside down</td>
#       <td>6IMdD50UNZOZxGro2bgsnN</td>
#       <td>3.30</td>
#       <td><a href="https://open.spotify.com/track/6IMdD50UNZOZxGro2bgsnN" target="_blank">https://open.spotify.com/track/6IMdD50UNZOZxGro2bgsnN</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>TOXIC - trainspotting</td>
#       <td>3mrtP5imQ3Mv3OQ0byI4ix</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/3mrtP5imQ3Mv3OQ0byI4ix" target="_blank">https://open.spotify.com/track/3mrtP5imQ3Mv3OQ0byI4ix</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>SONNY - city of god</td>
#       <td>3knzVyYsKLWzlzdBiZPHWB</td>
#       <td>3.18</td>
#       <td><a href="https://open.spotify.com/track/3knzVyYsKLWzlzdBiZPHWB" target="_blank">https://open.spotify.com/track/3knzVyYsKLWzlzdBiZPHWB</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>MC DRIVE - la haine</td>
#       <td>6xEKlNQQ5XcUXihEQ6wON7</td>
#       <td>3.00</td>
#       <td><a href="https://open.spotify.com/track/6xEKlNQQ5XcUXihEQ6wON7" target="_blank">https://open.spotify.com/track/6xEKlNQQ5XcUXihEQ6wON7</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>SENZ'ANIMA - nikita</td>
#       <td>39ZJEJ8KLq8yQQ1OEAdJ1W</td>
#       <td>3.22</td>
#       <td><a href="https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W" target="_blank">https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>ATTORI DI STRADA - ragazzi fuori</td>
#       <td>1VTZiz4hE2YSaJZZ83N5dr</td>
#       <td>3.51</td>
#       <td><a href="https://open.spotify.com/track/1VTZiz4hE2YSaJZZ83N5dr" target="_blank">https://open.spotify.com/track/1VTZiz4hE2YSaJZZ83N5dr</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>BEL FINALE - the butterfly effect</td>
#       <td>36IxxPEiwxT1TPRDsKXdxY</td>
#       <td>1.86</td>
#       <td><a href="https://open.spotify.com/track/36IxxPEiwxT1TPRDsKXdxY" target="_blank">https://open.spotify.com/track/36IxxPEiwxT1TPRDsKXdxY</a></td>
#       <td>Effetto notte</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Sulla luna (intro)</td>
#       <td>3nKA4HNuLw8oRvjBjY116r</td>
#       <td>2.09</td>
#       <td><a href="https://open.spotify.com/track/3nKA4HNuLw8oRvjBjY116r" target="_blank">https://open.spotify.com/track/3nKA4HNuLw8oRvjBjY116r</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Cashwoman</td>
#       <td>3diNNevWuOFP00rJs51EcF</td>
#       <td>2.79</td>
#       <td><a href="https://open.spotify.com/track/3diNNevWuOFP00rJs51EcF" target="_blank">https://open.spotify.com/track/3diNNevWuOFP00rJs51EcF</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Parole di ghiaccio</td>
#       <td>3IR20zWyql3UyURiPs5RaB</td>
#       <td>3.73</td>
#       <td><a href="https://open.spotify.com/track/3IR20zWyql3UyURiPs5RaB" target="_blank">https://open.spotify.com/track/3IR20zWyql3UyURiPs5RaB</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Dietro front (feat. Fabri Fibra)</td>
#       <td>7h92cTYpnRSYpV25sixGlm</td>
#       <td>3.10</td>
#       <td><a href="https://open.spotify.com/track/7h92cTYpnRSYpV25sixGlm" target="_blank">https://open.spotify.com/track/7h92cTYpnRSYpV25sixGlm</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Come un pitbull</td>
#       <td>0VeRBqohOzb3nF8KhYQwEK</td>
#       <td>3.63</td>
#       <td><a href="https://open.spotify.com/track/0VeRBqohOzb3nF8KhYQwEK" target="_blank">https://open.spotify.com/track/0VeRBqohOzb3nF8KhYQwEK</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Ognuno per sè (feat. Guè)</td>
#       <td>1pegcvjD0vrZrHUOmiifUA</td>
#       <td>3.14</td>
#       <td><a href="https://open.spotify.com/track/1pegcvjD0vrZrHUOmiifUA" target="_blank">https://open.spotify.com/track/1pegcvjD0vrZrHUOmiifUA</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>L'erba cattiva</td>
#       <td>4hoyFHWi1812CUl4FCFVXt</td>
#       <td>3.81</td>
#       <td><a href="https://open.spotify.com/track/4hoyFHWi1812CUl4FCFVXt" target="_blank">https://open.spotify.com/track/4hoyFHWi1812CUl4FCFVXt</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Cocktailz (feat. G. Soave & Duellz)</td>
#       <td>3k3LP2DUyT9mDhaaZNcob9</td>
#       <td>3.41</td>
#       <td><a href="https://open.spotify.com/track/3k3LP2DUyT9mDhaaZNcob9" target="_blank">https://open.spotify.com/track/3k3LP2DUyT9mDhaaZNcob9</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Nice pic</td>
#       <td>6xb8eMUgjdELMBcNM96va4</td>
#       <td>3.09</td>
#       <td><a href="https://open.spotify.com/track/6xb8eMUgjdELMBcNM96va4" target="_blank">https://open.spotify.com/track/6xb8eMUgjdELMBcNM96va4</a></td>
#       <td>L'erba cattiva (10 Years Anniversary Edition)</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Nei guai (feat. Tormento)</td>
#       <td>2CGvZZnXy6TfrJ4PBKdK86</td>
#       <td>3.15</td>
#       <td><a href="https://open.spotify.com/track/2CGvZZnXy6TfrJ4PBKdK86" target="_blank">https://open.sp

# %% [markdown]
# Un'altra interessante funzionalità che possiamo sfruttare è quella di ottenere la top 10 dei brani di un artista arbitrario.<br>
# In particolare siamo interessati ai seguenti campi:
# - Titolo
# - ID
# - Popolarità
# - Durata
# - Data di rilascio
# - Album
# - Spotify URL

# %%
def get_top_tracks_artist(token, artist_id):
    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=IT"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  
        data = response.json()["tracks"]
        return data
        
    except requests.exceptions.RequestException as e:
        print(f"Errore nella richiesta HTTP: {e}")
        return None

# %%
top_tracks = get_top_tracks_artist(access_token, artist_data['ID'])

top_tracks_data_frame = pd.DataFrame([{
    'Titolo': track['name'],
    'ID': track['id'],
    'Popolarità': track['popularity'],
    'Durata': convert_duration(track['duration_ms']),
    'Data di rilascio': track['album']['release_date'],
    'Album' : track["album"]["name"],
    'Spotify URL': track['external_urls']['spotify']
} for track in top_tracks])
top_tracks_data_frame['Spotify URL'] = top_tracks_data_frame['Spotify URL'].apply(make_clickable)

print(f"Top Tracks dell'artista {artist_name} :\n")
display(HTML(top_tracks_data_frame.to_html(escape=False)))
# Out:
# Top Tracks dell'artista Emis Killa :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Popolarità</th>
#       <th>Durata</th>
#       <th>Data di rilascio</th>
#       <th>Album</th>
#       <th>Spotify URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ON FIRE - paid in full</td>
#       <td>2pGbOFiWVwZaTq3iKi5sGb</td>
#       <td>66</td>
#       <td>2.93</td>
#       <td>2023-05-19</td>
#       <td>Effetto notte</td>
#       <td><a href="https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb" target="_blank">https://open.spotify.com/track/2pGbOFiWVwZaTq3iKi5sGb</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SENZ'ANIMA - nikita</td>
#       <td>39ZJEJ8KLq8yQQ1OEAdJ1W</td>
#       <td>64</td>
#       <td>3.22</td>
#       <td>2023-05-19</td>
#       <td>Effetto notte</td>
#       <td><a href="https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W" target="_blank">https://open.spotify.com/track/39ZJEJ8KLq8yQQ1OEAdJ1W</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Fuoco e benzina</td>
#       <td>4Fs1sEg9Mwn6vykFD89xvc</td>
#       <td>63</td>
#       <td>3.49</td>
#       <td>2018-10-12</td>
#       <td>Supereroe</td>
#       <td><a href="https://open.spotify.com/track/4Fs1sEg9Mwn6vykFD89xvc" target="_blank">https://open.spotify.com/track/4Fs1sEg9Mwn6vykFD89xvc</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mon Fre - feat. Emis Killa</td>
#       <td>4dDMgEj5GpBTI1lvVlYPu7</td>
#       <td>62</td>
#       <td>3.74</td>
#       <td>2019-07-19</td>
#       <td>Mon Fre (feat. Emis Killa)</td>
#       <td><a href="https://open.spotify.com/track/4dDMgEj5GpBTI1lvVlYPu7" target="_blank">https://open.spotify.com/track/4dDMgEj5GpBTI1lvVlYPu7</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Parole di ghiaccio</td>
#       <td>1mItEeAlTepKfWUOpu8h6b</td>
#       <td>60</td>
#       <td>3.86</td>
#       <td>2012-02-07</td>
#       <td>L'erba cattiva</td>
#       <td><a href="https://open.spotify.com/track/1mItEeAlTepKfWUOpu8h6b" target="_blank">https://open.spotify.com/track/1mItEeAlTepKfWUOpu8h6b</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Rollercoaster</td>
#       <td>4WJj8NsyCm3YAADCOe0hrf</td>
#       <td>56</td>
#       <td>3.46</td>
#       <td>2018-10-12</td>
#       <td>Supereroe</td>
#       <td><a href="https://open.spotify.com/track/4WJj8NsyCm3YAADCOe0hrf" target="_blank">https://open.spotify.com/track/4WJj8NsyCm3YAADCOe0hrf</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>PAROLA - feat. Lazza, Emis Killa</td>
#       <td>4XxQOwmNM0DF3bKafSJBNw</td>
#       <td>52</td>
#       <td>3.39</td>
#       <td>2020-04-09</td>
#       <td>CHIC</td>
#       <td><a href="https://open.spotify.com/track/4XxQOwmNM0DF3bKafSJBNw" target="_blank">https://open.spotify.com/track/4XxQOwmNM0DF3bKafSJBNw</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>L'ultima volta - feat. Massimo Pericolo</td>
#       <td>3rOw9WmYFCRLHTRcbOjhUl</td>
#       <td>58</td>
#       <td>3.52</td>
#       <td>2020-09-18</td>
#       <td>17</td>
#       <td><a href="https://open.spotify.com/track/3rOw9WmYFCRLHTRcbOjhUl" target="_blank">https://open.spotify.com/track/3rOw9WmYFCRLHTRcbOjhUl</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>No Cap (feat. Geolier)</td>
#       <td>3uqFFmxrCv4nzkKFSNbXHv</td>
#       <td>57</td>
#       <td>3.22</td>
#       <td>2021-02-26</td>
#       <td>17 - Dark Edition</td>
#       <td><a href="https://open.spotify.com/track/3uqFFmxrCv4nzkKFSNbXHv" target="_blank">https://open.spotify.com/track/3uqFFmxrCv4nzkKFSNbXHv</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Quella foto di noi due</td>
#       <td>10hc6GvyWhe2E48PAfQrdD</td>
#       <td>57</td>
#       <td>3.25</td>
#       <td>2018-10-12</td>
#       <td>Supereroe</td>
#       <td><a href="https://open.spotify.com/track/10hc6GvyWhe2E48PAfQrdD" target="_blank">https://open.spotify.com/track/10hc6GvyWhe2E48PAfQrdD</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Possiamo usare le API REST di Spotify per ottenere anche informazioni sugli artisti correlati ad un artista in particolare

# %%
def get_artist_related(token, id):
    url = f"https://api.spotify.com/v1/artists/{id}/related-artists"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() 
        data = response.json()["artists"]
        return data
    except requests.exceptions.RequestException as e:
        print(f"Errore nella richiesta HTTP: {e}")
        return None

# %%
artists = get_artist_related(access_token, artist_data['ID'])

artists_data = pd.DataFrame([{
    'Nome' : artist["name"],
    'ID': artist['id'],
    'Genere': artist['genres'][0],
    'Popolarità': artist['popularity'],
    'Followers' : artist["followers"]["total"],
    'Spotify URL': artist['external_urls']['spotify'],
    "Immagine": artist["images"][0]["url"]
} for artist in artists])

artists_data_frame = pd.DataFrame(artists_data)
artists_data_frame['Spotify URL'] = artists_data_frame['Spotify URL'].apply(make_clickable)
artists_data_frame['Immagine'] = artists_data_frame['Immagine'].apply(display_image)
artists_data_frame = artists_data_frame.sort_values(by='Followers',ascending=False)
artists_data_frame= artists_data_frame.reset_index(drop=True)

print(f'Artisti correlati:\n')
display(HTML(artists_data_frame.to_html(escape=False)))
# Out:
# Artisti correlati:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nome</th>
#       <th>ID</th>
#       <th>Genere</th>
#       <th>Popolarità</th>
#       <th>Followers</th>
#       <th>Spotify URL</th>
#       <th>Immagine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Guè</td>
#       <td>7F2utINZ6tSokSiZTQBE27</td>
#       <td>italian hip hop</td>
#       <td>72</td>
#       <td>2348000</td>
#       <td><a href="https://open.spotify.com/artist/7F2utINZ6tSokSiZTQBE27" target="_blank">https://open.spotify.com/artist/7F2utINZ6tSokSiZTQBE27</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebf6a1f6a347d77ea46a24192d" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Gemitaiz</td>
#       <td>4upwdFMlZBmQ68jP9jPzjK</td>
#       <td>italian hip hop</td>
#       <td>64</td>
#       <td>2066620</td>
#       <td><a href="https://open.spotify.com/artist/4upwdFMlZBmQ68jP9jPzjK" target="_blank">https://open.spotify.com/artist/4upwdFMlZBmQ68jP9jPzjK</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb7da5f11d322585184fcfb2bd" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Tedua</td>
#       <td>1AgAVqo74e2q4FVvg0xpT7</td>
#       <td>indie liguria</td>
#       <td>70</td>
#       <td>1571291</td>
#       <td><a href="https://open.spotify.com/artist/1AgAVqo74e2q4FVvg0xpT7" target="_blank">https://open.spotify.com/artist/1AgAVqo74e2q4FVvg0xpT7</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebc6515cd6270319e01ecf18b7" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Dark Polo Gang</td>
#       <td>4CuMwzDzEdlUJMEna38VQ0</td>
#       <td>italian hip hop</td>
#       <td>54</td>
#       <td>1359626</td>
#       <td><a href="https://open.spotify.com/artist/4CuMwzDzEdlUJMEna38VQ0" target="_blank">https://open.spotify.com/artist/4CuMwzDzEdlUJMEna38VQ0</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb27ef01a02f53e0328aa034c6" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>MadMan</td>
#       <td>3MkkSf3u5KU52Mb2iMrqeX</td>
#       <td>italian hip hop</td>
#       <td>58</td>
#       <td>1222591</td>
#       <td><a href="https://open.spotify.com/artist/3MkkSf3u5KU52Mb2iMrqeX" target="_blank">https://open.spotify.com/artist/3MkkSf3u5KU52Mb2iMrqeX</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb61f9d4d54c15b4cfda10bd04" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Vegas Jones</td>
#       <td>4b3MWJACM6T1QwGKoFe7pp</td>
#       <td>italian hip hop</td>
#       <td>50</td>
#       <td>937824</td>
#       <td><a href="https://open.spotify.com/artist/4b3MWJACM6T1QwGKoFe7pp" target="_blank">https://open.spotify.com/artist/4b3MWJACM6T1QwGKoFe7pp</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebfb973cc5add78a32e6f03f74" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Izi</td>
#       <td>6289Bbkkk3gaCbh1K7Rv8F</td>
#       <td>indie liguria</td>
#       <td>57</td>
#       <td>918605</td>
#       <td><a href="https://open.spotify.com/artist/6289Bbkkk3gaCbh1K7Rv8F" target="_blank">https://open.spotify.com/artist/6289Bbkkk3gaCbh1K7Rv8F</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb073ff5ab47e3987e782f08c2" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Ernia</td>
#       <td>3fhMfkPPzksWuw0hEm4ldm</td>
#       <td>italian hip hop</td>
#       <td>64</td>
#       <td>872895</td>
#       <td><a href="https://open.spotify.com/artist/3fhMfkPPzksWuw0hEm4ldm" target="_blank">https://open.spotify.com/artist/3fhMfkPPzksWuw0hEm4ldm</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebfc9ae482b4fdedc7210d5ff2" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Noyz Narcos</td>
#       <td>49UAapOfpOg1ZOU4xf2NgY</td>
#       <td>italian hip hop</td>
#       <td>69</td>
#       <td>764722</td>
#       <td><a href="https://open.spotify.com/artist/49UAapOfpOg1ZOU4xf2NgY" target="_blank">https://open.spotify.com/artist/49UAapOfpOg1ZOU4xf2NgY</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb599bf5b2884580b1c7ae5920" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Nitro</td>
#       <td>6jQZzWW3JlEtcRDSzFVKSP</td>
#       <td>italian hip hop</td>
#       <td>59</td>
#       <td>673902</td>
#       <td><a href="https://open.spotify.com/artist/6jQZzWW3JlEtcRDSzFVKSP" target="_blank">https://open.spotify.com/artist/6jQZzWW3JlEtcRDSzFVKSP</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb9cce35e850e54787804c149b" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Charlie Charles</td>
#       <td>1UCxzrM5WJh9ure5vCcsim</td>
#       <td>italian hip hop</td>
#       <td>48</td>
#       <td>516450</td>
#       <td><a href="https://open.spotify.com/artist/1UCxzrM5WJh9ure5vCcsim" target="_blank">https://open.spotify.com/artist/1UCxzrM5WJh9ure5vCcsim</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb45bc5b4376d4216d777880ec" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Nayt</td>
#       <td>7tmTvmqgTBcX88ZrSHByrD</td>
#       <td>italian hip hop</td>
#       <td>57</td>
#       <td>514209</td>
#       <td><a href="https://open.spotify.com/artist/7tmTvmqgTBcX88ZrSHByrD" target="_blank">https://open.spotify.com/artist/7tmTvmqgTBcX88ZrSHByrD</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebbad01c594427af3446cfaef4" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Massimo Pericolo</td>
#       <td>1El4YQA8oCXX7ynFSxRTFq</td>
#       <td>italian hip hop</td>
#       <td>59</td>
#       <td>513615</td>
#       <td><a href="https://open.spotify.com/artist/1El4YQA8oCXX7ynFSxRTFq" target="_blank">https://open.spotify.com/artist/1El4YQA8oCXX7ynFSxRTFq</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb6574165321b1c7c548423182" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Club Dogo</td>
#       <td>4dyfAiJCbl7jS1GHOCdiJv</td>
#       <td>italian hip hop</td>
#       <td>56</td>
#       <td>485164</td>
#       <td><a href="https://open.spotify.com/artist/4dyfAiJCbl7jS1GHOCdiJv" target="_blank">https://open.spotify.com/artist/4dyfAiJCbl7jS1GHOCdiJv</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb7ea1c19874e1470cb83c4640" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Jake La Furia</td>
#       <td>6JFRI91YaCXREGQYzHSnUH</td>
#       <td>italian hip hop</td>
#       <td>54</td>
#       <td>428530</td>
#       <td><a href="https://open.spotify.com/artist/6JFRI91YaCXREGQYzHSnUH" target="_blank">https://open.spotify.com/artist/6JFRI91YaCXREGQYzHSnUH</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb488ba47c5fb47fae5d293d20" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Mostro</td>
#       <td>5dPBeuSKtu5vLz1Et8YSVv</td>
#       <td>italian hip hop</td>
#       <td>56</td>
#       <td>402042</td>
#       <td><a href="https://open.spotify.com/artist/5dPBeuSKtu5vLz1Et8YSVv" target="_blank">https://open.spotify.com/artist/5dPBeuSKtu5vLz1Et8YSVv</a></td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb4386a1324bbd9d99cf62ef08" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Dani Faiv</td>
#       <td>0

# %% [markdown]
# Utilizzando gli <strong>ID</strong> delle singole canzoni, è possibile recuperare integralmente i dettagli di ciascun brano.<br>
# Siamo interessati a :
# - Titolo
# - ID
# - Durata
# - Data di rilascio
# - Popolarità
# - Spotify URL
# - Titolo dell'album di appartenenza
# - Copertina dell'album di appartenenza

# %%
def get_track_details(access_token, track_id):
    url = f'https://api.spotify.com/v1/tracks/{track_id}'
    headers = {
        'Authorization': f'Bearer {access_token}'
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Solleva un'eccezione se la richiesta HTTP non ha successo
        track_data = response.json()
        return track_data

    except requests.exceptions.RequestException as e:
        raise Exception(f"Errore nella richiesta HTTP: {e}")

# %%
track_name = "Mercurio"
track_id = discography_data_frame.loc[discography_data_frame['Titolo'] == track_name, 'ID'].values[0]

track_details = get_track_details(access_token, track_id)

track_data_frame = pd.DataFrame({
    'Titolo': [track_details['name']],
    'ID': [track_details['id']],
    'Durata': [convert_duration(track_details['duration_ms'])],  # Applica la conversione della durata
    'Data di rilascio': [track_details['album']['release_date']],
    'Popolarità': [track_details['popularity']],
    'Spotify URL': [extract_spotify_url(track_details['external_urls'])],
    'Album': [track_details['album']['name']],
    'Copertina': [track_details['album']['images'][0]['url']]
})

track_data_frame['Spotify URL'] = track_data_frame['Spotify URL'].apply(make_clickable)
track_data_frame['Copertina'] = track_data_frame['Copertina'].apply(display_image)

HTML(track_data_frame.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Titolo</th>
#       <th>ID</th>
#       <th>Durata</th>
#       <th>Data di rilascio</th>
#       <th>Popolarità</th>
#       <th>Spotify URL</th>
#       <th>Album</th>
#       <th>Copertina</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Mercurio</td>
#       <td>3bB8EUEbfFiIa6RyaYZeMt</td>
#       <td>3.72</td>
#       <td>2014-06-10</td>
#       <td>31</td>
#       <td><a href="https://open.spotify.com/track/3bB8EUEbfFiIa6RyaYZeMt" target="_blank">https://open.spotify.com/track/3bB8EUEbfFiIa6RyaYZeMt</a></td>
#       <td>Mercurio - 5 Stars Edition</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273b9eece34c479260d347da140" alt="Cover Image" style="max-height: 80px; max-width: 80px;"></td>
#     </tr>
#   </tbody>
# </table>

# %%
import urllib.parse
import secrets
from datetime import datetime
import webbrowser

# Definizione delle costanti
REDIRECT_URI = "http://localhost:5000/callback"
TOKEN_URL = "https://accounts.spotify.com/api/token"
AUTH_URL = "https://accounts.spotify.com/authorize"
API_BASE_URL = "https://api.spotify.com/v1/"

# Generazione di uno stato sicuro
state = secrets.token_urlsafe(16)

# Definizione dello scope
scope = 'user-read-private user-top-read user-read-email user-follow-read playlist-modify-private playlist-modify-public user-follow-modify user-library-read'

# Costruzione dei parametri per l'autorizzazione
auth_params = {
    'client_id': client_id,
    'response_type': 'code',
    'scope': scope,
    'redirect_uri': REDIRECT_URI,
    'show_dialog': True,
    'state': state
}

# Costruzione dell'URL di autorizzazione
auth_url = f"{AUTH_URL}?{urllib.parse.urlencode(auth_params)}"

# Apertura automatica dell'URL nel browser
webbrowser.open(auth_url, new=2)

# Stampa di un messaggio informativo
print(f'Si aprirà una finestra del browser. Dopo aver autorizzato l\'app, copia l\'URL della pagina ed incollalo qui di seguito.')

# Ricezione dell'URL di callback in modo automatico
callback_url = input("Incolla l'URL della pagina qui: ")
url_components = urllib.parse.urlparse(callback_url)
query_params = urllib.parse.parse_qs(url_components.query)

# Rimuovi il messaggio informativo sulla finestra del browser
print('\033[F\033[F\033[F\033[F\033[F\033[F\033[F')

# Estrazione del codice di autorizzazione dalla risposta di callback
authorization_code = query_params.get('code')

# Costruzione del corpo della richiesta per ottenere il token di accesso
token_request_body = {
    'code': authorization_code,
    'grant_type': 'authorization_code',
    'redirect_uri': REDIRECT_URI,
    'client_id': client_id,
    'client_secret': client_secret
}

# Richiesta del token di accesso
token_response = requests.post(TOKEN_URL, data=token_request_body)
token_info = token_response.json()

# Estrazione delle informazioni dal token di accesso
access_token = token_info.get('access_token')
refresh_token = token_info.get('refresh_token')
expires_at = datetime.now().timestamp() + token_info.get('expires_in', 3600)

# Creazione dell'header di autorizzazione per le future richieste all'API di Spotify
headers = {
    'Authorization': f'Bearer {access_token}'
}
# Out:
# Si aprirà una finestra del browser. Dopo aver autorizzato l'app, copia l'URL della pagina ed incollalo qui di seguito.
# Incolla l'URL della pagina qui:  http://localhost:5000/callback?code=AQAy_-KG3IZW4vZk2viR8iC2pI0E2QxleO0P3oukhJp4LkIcvy1JLLVgpYaYE9p0aOURodSvYx_6MbOitnicVzCqBMEAzSwrBg3aMJeR4DZxmMBGhr-RxS4i-T3UgnNTnYAcT9AO5SL28T8m79sXd9psFMHobwhCsjOiWJmWYU5quz59078hJoUXYy0FP6BDXWa5WGw6uhKjUIZn-S73m3MxB37mpx6DVMpwUvgSh_yrfrNZzk1h3LVXeCpHDEM3KSoA5xSkgng1GYYSHEh_S84PubBanqsaWrUGjmICCEnUx9yd0OQFgMICxe3dPKCW45H-LNfr1_qlGMsXtFs7TyY_9jbVejN_zi9FScct5K2Oo3lMnN3O3n-y9KfqPRM&state=bAVUWKcoe0t4CDnRrnC1hQ

# %% [markdown]
# Dopo aver eseguito l'autenticazione secondo le regole definite dal protocollo Oauth, sarà possibile accedere a molte altre funzionalità predisposte dalle API di Spotify. Iniziamo dall'ottenere banalmente il profilo dell'utente che si è autenticato, otterremo informazioni come :
# - Nome
# - ID
# - E-mail
# - Paese
# - Followers

# %%
def get_current_user_profile(access_token):
    url = 'https://api.spotify.com/v1/me'
    
    headers = {
        'Authorization': f'Bearer {access_token}'
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Solleva un'eccezione se la richiesta HTTP non ha successo

        user_data = response.json()
        return user_data

    except requests.exceptions.HTTPError as e:
        # Dettagli specifici sull'errore
        if response.status_code == 401:
            raise Exception("Accesso non autorizzato. L'access token potrebbe essere scaduto o non valido.")
        else:
            raise Exception(f"Errore nella richiesta HTTP: {e}")
    except requests.exceptions.RequestException as e:
        raise Exception(f"Errore nella richiesta HTTP: {e}")

# %%
client_details = get_current_user_profile(access_token)

user_data = {
    'Nome': client_details.get('display_name', ''),
    'ID': client_details.get('id', ''),
    'E-mail': client_details.get('email', ''),
    'Paese': client_details.get('country', ''),
    'Followers': client_details.get('followers', {}).get('total', 0),
    'Spotify URL': extract_spotify_url(client_details.get('external_urls', {}))
}

client_data_frame = pd.DataFrame([user_data], columns=['Nome', 'ID', 'E-mail', 'Paese', 'Followers', 'Spotify URL'])
df['Spotify URL'] = df['Spotify URL'].apply(make_clickable)

HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nome</th>
#       <th>ID</th>
#       <th>E-mail</th>
#       <th>Paese</th>
#       <th>Followers</th>
#       <th>Spotify URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfio.spoto</td>
#       <td>utjivvjkuupoikc3rtyb7rpu0</td>
#       <td>alfio.spoto@outlook.it</td>
#       <td>IT</td>
#       <td>0</td>
#       <td><a href="https://open.spotify.com/user/utjivvjkuupoikc3rtyb7rpu0" target="_blank">https://open.spotify.com/user/utjivvjkuupoikc3rtyb7rpu0</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <section id="estrazione-dati-e-analisi">
#     <h2>7. Estrazione dati e analisi</h2>
# </section>

# %%
# artisti diversi

# %% [markdown]
# <section id="conclusione">
#     <h2>8. Conclusione</h2>
# </section>
