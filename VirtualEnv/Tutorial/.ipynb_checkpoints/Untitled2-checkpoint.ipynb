# %%
from requests import post, get
import base64
import os
import json

# %%
CLIENT_ID = '92c7e8974c32468bb7f8fdba1d898847'
SECRET_ID = 'a23b031188f34caca5c97bc7851c2192'

# %%
def get_token_access():
    auth_string = f"{CLIENT_ID}:{SECRET_ID}"
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": f"Basic {auth_base64}",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    result = requests.post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result["access_token"]
    return token

# %%
#API SEARCH
import requests
import json

def search_artist(token, artist_name):
    url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "q": artist_name,
        "type": "artist",
        "limit": 1
    }
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        #utilizziamo json in modo che i dati possono essere facilmente manipolati e utilizzati 
        data = json.loads(response.content)["artists"]["items"]
        return data[0]
    else:
        print(f"Errore nella richiesta HTTP: {response.status_code}")
        return None

# %%
access_token = get_token_access()
result = search_artist(access_token, "Calcutta")
print(result)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'}, 'followers': {'href': None, 'total': 659897}, 'genres': ['italian adult pop', 'italian pop', 'rome indie'], 'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r', 'id': '582KhTHEVOONNQLmQ5612r', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebe6f42fb00b849720936df798', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174e6f42fb00b849720936df798', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178e6f42fb00b849720936df798', 'width': 160}], 'name': 'Calcutta ', 'popularity': 67, 'type': 'artist', 'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}

# %%
#estraggo le informazioni inerenti al nome, id , url, genere ,follower e immagine della nostra ricerca

artist_name = result["name"]
artist_id = result["id"] #spotify id for the artist
artist_url = result["external_urls"]["spotify"] #the spotify url for the object 
artist_genres = result["genres"]
artist_followers = result["followers"]["total"]
artist_image = result["images"][0]["url"]

# %%
import pandas as pd
from IPython.display import Image, display, HTML

#creo un dizionario
artist_data = {
    "NAME": [artist_name],
    "ID": [artist_id],
    "SPOTIFY URL": [artist_url],
    "GENERE": [artist_genres],
    "FOLLOWER": [artist_followers],
    "artist_image_url": [artist_image]
}
#permette di visualizzare il contenuto delle colonne senza troncarle in caso di tot lunghezza
pd.set_option('display.max_colwidth', None)
df = pd.DataFrame(artist_data)

image_width = 250
# Visualizza l'immagine cnetrata
image_html = f'<div style="display: flex; justify-content: center;">' \
             f'<img src="{df["artist_image_url"][0]}" alt="Artista" width="{image_width}" style="display: block;"/>' \
             f'</div>'
display(HTML(image_html))

#df drop rimuove la collone artist_image_url e visualizza il dataframe
display(df.drop("artist_image_url", axis=1))
# Out:
# <div style="display: flex; justify-content: center;"><img src="https://i.scdn.co/image/ab6761610000e5ebe6f42fb00b849720936df798" alt="Artista" width="250" style="display: block;"/></div>
#         NAME                      ID  \
# 0  Calcutta   582KhTHEVOONNQLmQ5612r
#
#                                               SPOTIFY URL  \
# 0  https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r
#
#                                          GENERE  FOLLOWER
# 0  [italian adult pop, italian pop, rome indie]    659897

# %%
#TRACK PIU FAMOSE DI QUEST'ARTISTA

def top_tracks_artist(token, artist_id):
    url=f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=IT"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        #utilizziamo json in modo che i dati possono essere facilmente manipolati e utilizzati 
        data = json.loads(response.content)["tracks"]
        return data
    else:
        print(f"Errore nella richiesta HTTP: {response.status_code}")
        return None

# %%
res = top_tracks_artist(access_token, artist_id)
res
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 214291,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300083'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7yS8LfvvFEhtGhKLk29j5a'},
#   'href': 'https://api.spotify.com/v1/tracks/7yS8LfvvFEhtGhKLk29j5a',
#   'id': '7yS8LfvvFEhtGhKLk29j5a',
#   'is_local': False,
#   'is_playable': True,
#   'name': '2minuti',
#   'popularity': 74,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dec8bf0ded325c45c86117ee46815da09cc54996?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:7yS8LfvvFEhtGhKLk29j5a'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 250894,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300084'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3G5VUAzCpvaaWEMk9NkHFT'},
#   'href': 'https://api.spotify.com/v1/tracks/3G5VUAzCpvaaWEMk9NkHFT',
#   'id': '3G5VUAzCpvaaWEMk9NkHFT',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Tutti',
#   'popularity': 72,
#   'preview_url': 'https://p.scdn.co/mp3-preview/621ea3e32443f3837b262f595ebc7583946214ad?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:3G5VUAzCpvaaWEMk9NkHFT'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 204106,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300081'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7v4C0Bh0UUIr54Y7h86GPW'},
#   'href': 'https://api.spotify.com/v1/tracks/7v4C0Bh0UUIr54Y7h86GPW',
#   'id': '7v4C0Bh0UUIr54Y7h86GPW',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Giro con te',
#   'popularity': 71,
#   'preview_url': 'https://p.scdn.co/mp3-preview/18f2dc5d39781de5671bff1b4cf4143c56988c21?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:7v4C0Bh0UUIr54Y7h86GPW'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 224562,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300082'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0ofsKCwrfh6wigMU9IHsAF'},
#   'href': 'https://api.spotify.com/v1/tracks/0ofsKCwrfh6wigMU9IHsAF',
#   'id': '0ofsKCwrfh6wigMU9IHsAF',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Controtempo',
#   'popularity': 70,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5f8db42956a9f64159e5fe54a046a6592f98b7a2?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:0ofsKCwrfh6wigMU9IHsAF'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/11dh7pT3FRrGkI3TXl0e4k'},
#    'href': 'https://api.spotify.com/v1/albums/11dh7pT3FRrGkI3TXl0e4k',
#    'id': '11dh7pT3FRrGkI3TXl0e4k',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738417b499a1b885a9300a91eb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028417b499a1b885a9300a91eb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518417b499a1b885a9300a91eb',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Mainstream (Deluxe Edition)',
#    'release_date': '2016-06-03',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:11dh7pT3FRrGkI3TXl0e4k'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 169306,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITL771502058'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7L8cIUKXToCr6PV9hFoX3Q'},
#   'href': 'https://api.spotify.com/v1/tracks/7L8cIUKXToCr6PV9hFoX3Q',
#   'id': '7L8cIUKXToCr6PV9hFoX3Q',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Cosa mi manchi a fare',
#   'popularity': 70,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a5e8b98ae6ae1ccf226577060b84f878c9757a96?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:7L8cIUKXToCr6PV9hFoX3Q'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1ydmsbKjOxrWFBQmoz1O91'},
#    'href': 'https://api.spotify.com/v1/albums/1ydmsbKjOxrWFBQmoz1O91',
#    'id': '1ydmsbKjOxrWFBQmoz1O91',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c646c7e3234fec58ffe0d415',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c646c7e3234fec58ffe0d415',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c646c7e3234fec58ffe0d415',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Mainstream +',
#    'release_date': '2017-02-24',
#    'release_date_precision': 'day',
#    'total_tracks': 30,
#    'type': 'album',
#    'uri': 'spotify:album:1ydmsbKjOxrWFBQmoz1O91'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/76UCIJTB0jcJvBaL0CdIqx'},
#     'href': 'https://api.spotify.com/v1/artists/76UCIJTB0jcJvBaL0CdIqx',
#     'id': '76UCIJTB0jcJvBaL0CdIqx',
#     'name': 'Takagi & Ketra',
#     'type': 'artist',
#     'uri': 'spotify:artist:76UCIJTB0jcJvBaL0CdIqx'}],
#   'disc_number': 4,
#   'duration_ms': 198292,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITM381600065'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7yJZlPui7PYh2L9UXmtQWc'},
#   'href': 'https://api.spotify.com/v1/tracks/7yJZlPui7PYh2L9UXmtQWc',
#   'id': '7yJZlPui7PYh2L9UXmtQWc',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Oroscopo (feat. Takagi & Ketra) - Ghost track',
#   'popularity': 66,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a8ccfed997c2d58fb9912b75ae2be25a3c34f167?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:7yJZlPui7PYh2L9UXmtQWc'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 159074,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300087'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0HJd4ynGL3mn0p2o6WE9DI'},
#   'href': 'https://api.spotify.com/v1/tracks/0HJd4ynGL3mn0p2o6WE9DI',
#   'id': '0HJd4ynGL3mn0p2o6WE9DI',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Loneliness',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/83360f982ed56c6d7880fe6ad755c6659ceec798?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:0HJd4ynGL3mn0p2o6WE9DI'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 263157,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300086'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/79A1xsJMRAZzLhegAhH5CD'},
#   'href': 'https://api.spotify.com/v1/tracks/79A1xsJMRAZzLhegAhH5CD',
#   'id': '79A1xsJMRAZzLhegAhH5CD',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'SSD',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2f23f587c465a8ca0fb6ba12c4c322751ea9da3b?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:79A1xsJMRAZzLhegAhH5CD'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 218291,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300089'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6tgcr0z6mmLJL4qeRF6oen'},
#   'href': 'https://api.spotify.com/v1/tracks/6tgcr0z6mmLJL4qeRF6oen',
#   'id': '6tgcr0z6mmLJL4qeRF6oen',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Preoccuparmi',
#   'popularity': 66,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e7e1eb9c331f4cdbd56882034b9e7f1231058879?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:6tgcr0z6mmLJL4qeRF6oen'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#      'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#      'id': '582KhTHEVOONNQLmQ5612r',
#      'name': 'Calcutta ',
#      'type': 'artist',
#      'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#    'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#    'id': '4fPV5OWBxzBVaYRbXduGtj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'RELAX',
#    'release_date': '2023-10-20',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'disc_number': 1,
#   'duration_ms': 187315,
#   'explicit': False,
#   'external_ids': {'isrc': 'ITLGE2300088'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1fz4ovlT1RvvkokF1GRuYF'},
#   'href': 'https://api.spotify.com/v1/tracks/1fz4ovlT1RvvkokF1GRuYF',
#   'id': '1fz4ovlT1RvvkokF1GRuYF',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Ghiaccioli',
#   'popularity': 66,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bca611a906297be5413659bdd993bcd5c395c6fa?cid=92c7e8974c32468bb7f8fdba1d898847',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:1fz4ovlT1RvvkokF1GRuYF'}]

# %%
#alcuni dati inerenti ad una singola canzone
artist_uri= res[0]["uri"]
preview_track = res[0]["preview_url"]
number_track = res[0]["track_number"]
popularity_track = res[0]["popularity"]
name_track = res[0]["name"]
link = res[0]["external_urls"]["spotify"]
id_track = res[0]["id"]
duration_ms = res[0]['duration_ms']

print(res[0]["album"]["name"])
print(res[0]["album"]["images"][0]["url"])
print(res[0]["album"]["total_tracks"])
# Out:
# RELAX
# https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6
# 11

# %%
#andiamo a visualizzare corettamente la playlist

df = pd.DataFrame([{
    'Titolo': song['name'],
    #ci sono 60000 ms in un minuto con la divisione andiamo a prendere i minuti, dopodiche prendiamo il resto dei ms
    #dividendo per 1000 otteniamo i secondi e prendiamo solo le prime due cifre intere
    'Durata': f"{song['duration_ms'] // 60000}:{(song['duration_ms'] % 60000) // 1000:02d}",
    'Nome Album' : song["album"]["name"],
    'Song URL': song['external_urls']['spotify']
} for song in res])


#miglioriamo lo stile di visualizzazione del dataframe
styled_df = df.style.set_properties(**{'text-align': 'left'})\
            .set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}])\
            .format({'Song URL': '<a href="{}">Listen here</a>'}) #formattazione url come pulsante da cliccare

display(styled_df)
# Out:
# <style type="text/css">
# #T_408ff th {
#   text-align: left;
# }
# #T_408ff_row0_col0, #T_408ff_row0_col1, #T_408ff_row0_col2, #T_408ff_row0_col3, #T_408ff_row1_col0, #T_408ff_row1_col1, #T_408ff_row1_col2, #T_408ff_row1_col3, #T_408ff_row2_col0, #T_408ff_row2_col1, #T_408ff_row2_col2, #T_408ff_row2_col3, #T_408ff_row3_col0, #T_408ff_row3_col1, #T_408ff_row3_col2, #T_408ff_row3_col3, #T_408ff_row4_col0, #T_408ff_row4_col1, #T_408ff_row4_col2, #T_408ff_row4_col3, #T_408ff_row5_col0, #T_408ff_row5_col1, #T_408ff_row5_col2, #T_408ff_row5_col3, #T_408ff_row6_col0, #T_408ff_row6_col1, #T_408ff_row6_col2, #T_408ff_row6_col3, #T_408ff_row7_col0, #T_408ff_row7_col1, #T_408ff_row7_col2, #T_408ff_row7_col3, #T_408ff_row8_col0, #T_408ff_row8_col1, #T_408ff_row8_col2, #T_408ff_row8_col3, #T_408ff_row9_col0, #T_408ff_row9_col1, #T_408ff_row9_col2, #T_408ff_row9_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_408ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_408ff_level0_col0" class="col_heading level0 col0" >Titolo</th>
#       <th id="T_408ff_level0_col1" class="col_heading level0 col1" >Durata</th>
#       <th id="T_408ff_level0_col2" class="col_heading level0 col2" >Nome Album</th>
#       <th id="T_408ff_level0_col3" class="col_heading level0 col3" >Song URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_408ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_408ff_row0_col0" class="data row0 col0" >2minuti</td>
#       <td id="T_408ff_row0_col1" class="data row0 col1" >3:34</td>
#       <td id="T_408ff_row0_col2" class="data row0 col2" >RELAX</td>
#       <td id="T_408ff_row0_col3" class="data row0 col3" ><a href="https://open.spotify.com/track/7yS8LfvvFEhtGhKLk29j5a">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_408ff_row1_col0" class="data row1 col0" >Tutti</td>
#       <td id="T_408ff_row1_col1" class="data row1 col1" >4:10</td>
#       <td id="T_408ff_row1_col2" class="data row1 col2" >RELAX</td>
#       <td id="T_408ff_row1_col3" class="data row1 col3" ><a href="https://open.spotify.com/track/3G5VUAzCpvaaWEMk9NkHFT">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_408ff_row2_col0" class="data row2 col0" >Giro con te</td>
#       <td id="T_408ff_row2_col1" class="data row2 col1" >3:24</td>
#       <td id="T_408ff_row2_col2" class="data row2 col2" >RELAX</td>
#       <td id="T_408ff_row2_col3" class="data row2 col3" ><a href="https://open.spotify.com/track/7v4C0Bh0UUIr54Y7h86GPW">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_408ff_row3_col0" class="data row3 col0" >Controtempo</td>
#       <td id="T_408ff_row3_col1" class="data row3 col1" >3:44</td>
#       <td id="T_408ff_row3_col2" class="data row3 col2" >RELAX</td>
#       <td id="T_408ff_row3_col3" class="data row3 col3" ><a href="https://open.spotify.com/track/0ofsKCwrfh6wigMU9IHsAF">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_408ff_row4_col0" class="data row4 col0" >Cosa mi manchi a fare</td>
#       <td id="T_408ff_row4_col1" class="data row4 col1" >2:49</td>
#       <td id="T_408ff_row4_col2" class="data row4 col2" >Mainstream (Deluxe Edition)</td>
#       <td id="T_408ff_row4_col3" class="data row4 col3" ><a href="https://open.spotify.com/track/7L8cIUKXToCr6PV9hFoX3Q">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_408ff_row5_col0" class="data row5 col0" >Oroscopo (feat. Takagi & Ketra) - Ghost track</td>
#       <td id="T_408ff_row5_col1" class="data row5 col1" >3:18</td>
#       <td id="T_408ff_row5_col2" class="data row5 col2" >Mainstream +</td>
#       <td id="T_408ff_row5_col3" class="data row5 col3" ><a href="https://open.spotify.com/track/7yJZlPui7PYh2L9UXmtQWc">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_408ff_row6_col0" class="data row6 col0" >Loneliness</td>
#       <td id="T_408ff_row6_col1" class="data row6 col1" >2:39</td>
#       <td id="T_408ff_row6_col2" class="data row6 col2" >RELAX</td>
#       <td id="T_408ff_row6_col3" class="data row6 col3" ><a href="https://open.spotify.com/track/0HJd4ynGL3mn0p2o6WE9DI">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_408ff_row7_col0" class="data row7 col0" >SSD</td>
#       <td id="T_408ff_row7_col1" class="data row7 col1" >4:23</td>
#       <td id="T_408ff_row7_col2" class="data row7 col2" >RELAX</td>
#       <td id="T_408ff_row7_col3" class="data row7 col3" ><a href="https://open.spotify.com/track/79A1xsJMRAZzLhegAhH5CD">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_408ff_row8_col0" class="data row8 col0" >Preoccuparmi</td>
#       <td id="T_408ff_row8_col1" class="data row8 col1" >3:38</td>
#       <td id="T_408ff_row8_col2" class="data row8 col2" >RELAX</td>
#       <td id="T_408ff_row8_col3" class="data row8 col3" ><a href="https://open.spotify.com/track/6tgcr0z6mmLJL4qeRF6oen">Listen here</a></td>
#     </tr>
#     <tr>
#       <th id="T_408ff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_408ff_row9_col0" class="data row9 col0" >Ghiaccioli</td>
#       <td id="T_408ff_row9_col1" class="data row9 col1" >3:07</td>
#       <td id="T_408ff_row9_col2" class="data row9 col2" >RELAX</td>
#       <td id="T_408ff_row9_col3" class="data row9 col3" ><a href="https://open.spotify.com/track/1fz4ovlT1RvvkokF1GRuYF">Listen here</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
#PRENDE TUTTI GLI ALBUM FATTI DA UN ARTISTA
def get_artist_album(token, id):
    url=f"https://api.spotify.com/v1/artists/{id}/albums"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "market" : "IT",
        "limit": 10
    }
    response = requests.get(url, headers=headers, params= params)
    if response.status_code == 200:
        #utilizziamo json in modo che i dati possono essere facilmente manipolati e utilizzati 
        data = json.loads(response.content)["items"]
        return data
    else:
        print(f"Errore nella richiesta HTTP: {response.status_code}")
        return None

# %%
res = get_artist_album(access_token, artist_id)
res
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj'},
#   'href': 'https://api.spotify.com/v1/albums/4fPV5OWBxzBVaYRbXduGtj',
#   'id': '4fPV5OWBxzBVaYRbXduGtj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028acaa7da2fb43a4038d962c6',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518acaa7da2fb43a4038d962c6',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'RELAX',
#   'release_date': '2023-10-20',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:4fPV5OWBxzBVaYRbXduGtj'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0w267xHWJikkEIcQgfhezx'},
#   'href': 'https://api.spotify.com/v1/albums/0w267xHWJikkEIcQgfhezx',
#   'id': '0w267xHWJikkEIcQgfhezx',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732a7922dc3a775970e2eb96dc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022a7922dc3a775970e2eb96dc',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512a7922dc3a775970e2eb96dc',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Evergreen',
#   'release_date': '2018-05-25',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:0w267xHWJikkEIcQgfhezx'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1ydmsbKjOxrWFBQmoz1O91'},
#   'href': 'https://api.spotify.com/v1/albums/1ydmsbKjOxrWFBQmoz1O91',
#   'id': '1ydmsbKjOxrWFBQmoz1O91',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c646c7e3234fec58ffe0d415',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c646c7e3234fec58ffe0d415',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c646c7e3234fec58ffe0d415',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Mainstream +',
#   'release_date': '2017-02-24',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:1ydmsbKjOxrWFBQmoz1O91'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/11dh7pT3FRrGkI3TXl0e4k'},
#   'href': 'https://api.spotify.com/v1/albums/11dh7pT3FRrGkI3TXl0e4k',
#   'id': '11dh7pT3FRrGkI3TXl0e4k',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738417b499a1b885a9300a91eb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028417b499a1b885a9300a91eb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518417b499a1b885a9300a91eb',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Mainstream (Deluxe Edition)',
#   'release_date': '2016-06-03',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:11dh7pT3FRrGkI3TXl0e4k'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KkO9uXHF9BVNJASjLekAc'},
#     'href': 'https://api.spotify.com/v1/artists/2KkO9uXHF9BVNJASjLekAc',
#     'id': '2KkO9uXHF9BVNJASjLekAc',
#     'name': 'Franco126',
#     'type': 'artist',
#     'uri': 'spotify:artist:2KkO9uXHF9BVNJASjLekAc'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3gYKBnPZJ4mqsYzGCXIUNg'},
#   'href': 'https://api.spotify.com/v1/albums/3gYKBnPZJ4mqsYzGCXIUNg',
#   'id': '3gYKBnPZJ4mqsYzGCXIUNg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736329c403b6b03d6c2fdcdd93',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026329c403b6b03d6c2fdcdd93',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516329c403b6b03d6c2fdcdd93',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Blue Jeans (feat. Calcutta)',
#   'release_date': '2020-12-14',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3gYKBnPZJ4mqsYzGCXIUNg'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4Ul1mk94jBiMI5DXRhUstH'},
#   'href': 'https://api.spotify.com/v1/albums/4Ul1mk94jBiMI5DXRhUstH',
#   'id': '4Ul1mk94jBiMI5DXRhUstH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bab53b918fb49f85b4ffe40c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bab53b918fb49f85b4ffe40c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bab53b918fb49f85b4ffe40c',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Paracetamol',
#   'release_date': '2019-11-29',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4Ul1mk94jBiMI5DXRhUstH'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5U5pvv8NQHjb4UEhMozHRz'},
#   'href': 'https://api.spotify.com/v1/albums/5U5pvv8NQHjb4UEhMozHRz',
#   'id': '5U5pvv8NQHjb4UEhMozHRz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731c24f4acd080e23abe9b43db',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021c24f4acd080e23abe9b43db',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511c24f4acd080e23abe9b43db',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Sorriso (Milano Dateo)',
#   'release_date': '2019-06-07',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5U5pvv8NQHjb4UEhMozHRz'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3ziXGaOTjXGplPuXFKBRbE'},
#   'href': 'https://api.spotify.com/v1/albums/3ziXGaOTjXGplPuXFKBRbE',
#   'id': '3ziXGaOTjXGplPuXFKBRbE',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737daf9e9d08c2d2335fc1fd8c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027daf9e9d08c2d2335fc1fd8c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517daf9e9d08c2d2335fc1fd8c',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Due punti',
#   'release_date': '2019-05-31',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3ziXGaOTjXGplPuXFKBRbE'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/422Vo1v0NaW7ZVU8EwvhKW'},
#     'href': 'https://api.spotify.com/v1/artists/422Vo1v0NaW7ZVU8EwvhKW',
#     'id': '422Vo1v0NaW7ZVU8EwvhKW',
#     'name': 'Giorgio Poi',
#     'type': 'artist',
#     'uri': 'spotify:artist:422Vo1v0NaW7ZVU8EwvhKW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5LxsONz2erCptlVqTIB4FU'},
#   'href': 'https://api.spotify.com/v1/albums/5LxsONz2erCptlVqTIB4FU',
#   'id': '5LxsONz2erCptlVqTIB4FU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ae297b4d73ed2e6d36f15371',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ae297b4d73ed2e6d36f15371',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ae297b4d73ed2e6d36f15371',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'La Musica Italiana',
#   'release_date': '2019-01-23',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5LxsONz2erCptlVqTIB4FU'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/582KhTHEVOONNQLmQ5612r'},
#     'href': 'https://api.spotify.com/v1/artists/582KhTHEVOONNQLmQ5612r',
#     'id': '582KhTHEVOONNQLmQ5612r',
#     'name': 'Calcutta ',
#     'type': 'artist',
#     'uri': 'spotify:artist:582KhTHEVOONNQLmQ5612r'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2DWRgncNMnTfwDiKSI0VoP'},
#     'href': 'https://api.spotify.com/v1/artists/2DWRgncNMnTfwDiKSI0VoP',
#     'id': '2DWRgncNMnTfwDiKSI0VoP',
#     'name': 'TY1',
#     'type': 'artist',
#     'uri': 'spotify:artist:2DWRgncNMnTfwDiKSI0VoP'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7K11nS80JJz4tUnpSKc4YF'},
#   'href': 'https://api.spotify.com/v1/albums/7K11nS80JJz4tUnpSKc4YF',
#   'id': '7K11nS80JJz4tUnpSKc4YF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736d863c99405ec9c49520d389',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026d863c99405ec9c49520d389',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516d863c99405ec9c49520d389',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Paracetamolo (TY1 Remix)',
#   'release_date': '2018-07-06',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:7K11nS80JJz4tUnpSKc4YF'}]

# %%
df = pd.DataFrame([{
    'image' : album["images"][0]["url"],
    'Nome Album': album['name'],
    'Data di uscita': album['release_date'],
    'Numero di canzoni' : album["total_tracks"],
    'Album url': album['external_urls']['spotify']
} for album in res])

df['Immagine'] = df['image'].apply(lambda x: f'<img src="{x}" alt="Album Cover" style="max-height: 50px; max-width: 50px;">')

# Seleziona solo le colonne desiderate
selected_columns = ['Immagine','Nome Album', 'Data di uscita', 'Numero di canzoni', 'Album url']
df_selected = df[selected_columns]
df_selected = df_selected[df_selected['Numero di canzoni'] != 1] #eliminiamo playlist che hanno solo una canzone
 
# Visualizza il DataFrame con le immagini
display(HTML(df_selected.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Immagine</th>
#       <th>Nome Album</th>
#       <th>Data di uscita</th>
#       <th>Numero di canzoni</th>
#       <th>Album url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b2738acaa7da2fb43a4038d962c6" alt="Album Cover" style="max-height: 50px; max-width: 50px;"></td>
#       <td>RELAX</td>
#       <td>2023-10-20</td>
#       <td>11</td>
#       <td>https://open.spotify.com/album/4fPV5OWBxzBVaYRbXduGtj</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b2732a7922dc3a775970e2eb96dc" alt="Album Cover" style="max-height: 50px; max-width: 50px;"></td>
#       <td>Evergreen</td>
#       <td>2018-05-25</td>
#       <td>10</td>
#       <td>https://open.spotify.com/album/0w267xHWJikkEIcQgfhezx</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273c646c7e3234fec58ffe0d415" alt="Album Cover" style="max-height: 50px; max-width: 50px;"></td>
#       <td>Mainstream +</td>
#       <td>2017-02-24</td>
#       <td>30</td>
#       <td>https://open.spotify.com/album/1ydmsbKjOxrWFBQmoz1O91</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b2738417b499a1b885a9300a91eb" alt="Album Cover" style="max-height: 50px; max-width: 50px;"></td>
#       <td>Mainstream (Deluxe Edition)</td>
#       <td>2016-06-03</td>
#       <td>11</td>
#       <td>https://open.spotify.com/album/11dh7pT3FRrGkI3TXl0e4k</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_artist_related(token, id):
    url=f"https://api.spotify.com/v1/artists/{id}/related-artists"
    headers = {
        "Authorization": f"Bearer {token}"
    }
 
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        #utilizziamo json in modo che i dati possono essere facilmente manipolati e utilizzati 
        data = json.loads(response.content)["artists"]
        return data
    else:
        print(f"Errore nella richiesta HTTP: {response.status_code}")
        return None

# %%
results = get_artist_related(access_token, artist_id)


df = pd.DataFrame([{
    'name' : result["name"],
    'followers' : result["followers"]["total"],
     'image' : f'<img src="{result["images"][0]["url"]}" width="40" height="40">'
} for result in results])



df = df.sort_values(by='followers',ascending=False)
#reset degli indici
df= df.reset_index(drop=True)

display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>followers</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Coez</td>
#       <td>2085727</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb8044505721270eb00050b188" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Carl Brave</td>
#       <td>787372</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb72a61d0862006f8d73f560e3" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Gazzelle</td>
#       <td>780708</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb190531057abb2ba3419cf37a" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Frah Quintale</td>
#       <td>624369</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebb35b656a907a250278c4ecf5" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Carl Brave x Franco126</td>
#       <td>576784</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb14c91420457b538d29b1e685" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Franco126</td>
#       <td>340709</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb572dec71e436e9ee1b84b1a7" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Brunori Sas</td>
#       <td>308470</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebe933cd668648f409191efc99" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Lo Stato Sociale</td>
#       <td>281570</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebe5c7151c50deb485322eafc5" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Willie Peyote</td>
#       <td>251436</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb1d02014d68b1be34da84850f" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Coma_Cose</td>
#       <td>220529</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebf3eaf855c3bfb8f0e623fd36" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Cosmo</td>
#       <td>191137</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb0f7cf579a618fa43252c1347" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Canova</td>
#       <td>152025</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb007e1c66e4798a5fb05d9268" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>I Cani</td>
#       <td>131960</td>
#       <td><img src="https://i.scdn.co/image/ab67616d0000b273566737e323a84c13b37c51b7" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Ex-Otago</td>
#       <td>131440</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb49fa356d10944d4004306631" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Fulminacci</td>
#       <td>122067</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebae3a4cba261a56f7afac9acd" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Motta</td>
#       <td>119274</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb89893eb86ba9c42903418201" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Venerus</td>
#       <td>105757</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb89388c7103b36ae8598067f8" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Galeffi</td>
#       <td>92211</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb01391af1ba52528655ed71cc" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Giorgio Poi</td>
#       <td>64603</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5eb6048a0ede2ddd04f527263f8" width="40" height="40"></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Postino</td>
#       <td>31595</td>
#       <td><img src="https://i.scdn.co/image/ab6761610000e5ebc3eba285296c5092a838c224" width="40" height="40"></td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt

# Creare una lista dei nomi e una lista dei follower dai dati
names = df['name'].tolist()
followers = df['followers'].tolist()

plt.figure(figsize=(10, 6))
plt.plot(names, followers, marker='o', color='blue', linestyle='-')
plt.title('Popolarità in base ai follower')
plt.xlabel('Artista')
plt.ylabel('Follower')
plt.xticks(rotation=90)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [raw]
# #proviamo invece ora a capire la tendenza di musica in italia

# %%
def get_genres(token):
    url ="https://api.spotify.com/v1/recommendations/available-genre-seeds"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        #utilizziamo json in modo che i dati possono essere facilmente manipolati e utilizzati 
        data = json.loads(response.content)["genres"]
        return data
    else:
        print(f"Errore nella richiesta HTTP: {response.status_code}")
        return None

# %%
res=get_genres(access_token)
res
# Out:
# ['acoustic',
#  'afrobeat',
#  'alt-rock',
#  'alternative',
#  'ambient',
#  'anime',
#  'black-metal',
#  'bluegrass',
#  'blues',
#  'bossanova',
#  'brazil',
#  'breakbeat',
#  'british',
#  'cantopop',
#  'chicago-house',
#  'children',
#  'chill',
#  'classical',
#  'club',
#  'comedy',
#  'country',
#  'dance',
#  'dancehall',
#  'death-metal',
#  'deep-house',
#  'detroit-techno',
#  'disco',
#  'disney',
#  'drum-and-bass',
#  'dub',
#  'dubstep',
#  'edm',
#  'electro',
#  'electronic',
#  'emo',
#  'folk',
#  'forro',
#  'french',
#  'funk',
#  'garage',
#  'german',
#  'gospel',
#  'goth',
#  'grindcore',
#  'groove',
#  'grunge',
#  'guitar',
#  'happy',
#  'hard-rock',
#  'hardcore',
#  'hardstyle',
#  'heavy-metal',
#  'hip-hop',
#  'holidays',
#  'honky-tonk',
#  'house',
#  'idm',
#  'indian',
#  'indie',
#  'indie-pop',
#  'industrial',
#  'iranian',
#  'j-dance',
#  'j-idol',
#  'j-pop',
#  'j-rock',
#  'jazz',
#  'k-pop',
#  'kids',
#  'latin',
#  'latino',
#  'malay',
#  'mandopop',
#  'metal',
#  'metal-misc',
#  'metalcore',
#  'minimal-techno',
#  'movies',
#  'mpb',
#  'new-age',
#  'new-release',
#  'opera',
#  'pagode',
#  'party',
#  'philippines-opm',
#  'piano',
#  'pop',
#  'pop-film',
#  'post-dubstep',
#  'power-pop',
#  'progressive-house',
#  'psych-rock',
#  'punk',
#  'punk-rock',
#  'r-n-b',
#  'rainy-day',
#  'reggae',
#  'reggaeton',
#  'road-trip',
#  'rock',
#  'rock-n-roll',
#  'rockabilly',
#  'romance',
#  'sad',
#  'salsa',
#  'samba',
#  'sertanejo',
#  'show-tunes',
#  'singer-songwriter',
#  'ska',
#  'sleep',
#  'songwriter',
#  'soul',
#  'soundtracks',
#  'spanish',
#  'study',
#  'summer',
#  'swedish',
#  'synth-pop',
#  'tango',
#  'techno',
#  'trance',
#  'trip-hop',
#  'turkish',
#  'work-out',
#  'world-music']

# %%
import time


def new_dataframe(genres_list, token, limit=50):
    data = {
        'id_track': [],
        'name': [],
        'genre': []
    }

    headers = {
        'Authorization': f'Bearer {token}'
    }

    for genre in genres_list:
        params = {
            'q': f'genre:"{genre}"',
            'type': 'track',
            'limit': limit,
            'market' : 'IT'
        }

        # Esegui la richiesta HTTP GET
        response = requests.get("https://api.spotify.com/v1/search", headers=headers, params=params)

        if response.status_code == 200:
            results = response.json()

            for track in results['tracks']['items']:
                data['id_track'].append(track['id'])
                data['name'].append(track['name'])
                data['genre'].append(genre)

        # Aspetta per 2 secondi prima di effettuare la prossima richiesta
        time.sleep(1)

    return data


genres = [
    'acoustic', 'afrobeat','alt-rock', 'alternative', 'ambient', 'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova',
    'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical', 'club', 'comedy',
    'country', 'dance', 'dancehall', 'death-metal', 'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass',
    'dub', 'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german',
    'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
    'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop', 'industrial',
    'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop',
    'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode',
    'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-pop', 'progressive-house',
    'psych-rock', 'punk', 'punk-rock', 'r-n-b', 'rainy-day', 'reggae', 'reggaeton', 'road-trip', 'rock', 'rock-n-roll',
    'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes', 'singer-songwriter', 'ska', 'sleep',
    'songwriter', 'soul', 'soundtracks', 'spanish', 'study', 'summer', 'swedish', 'synth-pop', 'tango', 'techno',
    'trance', 'trip-hop', 'turkish', 'work-out', 'world-music']

# %%
res = new_dataframe(genres, access_token, limit=1)

# %%
res.info()
